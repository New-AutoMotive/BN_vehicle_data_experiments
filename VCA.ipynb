# %% [markdown]
# # Using VCA data to identify BEVs

# %% [markdown]
# We're going to try to use the VCA database to see whether we can identify:
# 1. vehicles that are BEV/PHEV/PETROL/DIESEL in veh0120, and
# 2. vehicles that are BEV/PHEV/PETROL/DIESEL in latest vehicle mileage estimates in our database

# %% [markdown]
# To test whether this is possible, we'll start by exploring some of the VCA data on emissions & vehicle types

# %%
#import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from zipfile import ZipFile

# %%
#First we'll import the latest 2020 vehicle emissions data
url_d20 = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/2020/data%20for%20guide%202020.zip'
df_d20 = pd.read_csv(url_d20, encoding='cp1252')

# %%
df_d20.head()
# Out:
#   Manufacturer Model                       Description Transmission  \
# 0       ABARTH   595                   595 1.4 145 BHP           M5
# 1       ABARTH   595                  595 1.4 145 BHP            M5
# 2       ABARTH   595              595 1.4 TJET 145 BHP           M5
# 3       ABARTH   595             595 1.4 TJET 145 BHP            M5
# 4       ABARTH   595  595 1.4 TJET 145 BHP Convertible           M5
#
#    Engine Capacity Fuel Type                        Powertrain  \
# 0             1368    Petrol  Internal Combustion Engine (ICE)
# 1             1368    Petrol  Internal Combustion Engine (ICE)
# 2             1368    Petrol  Internal Combustion Engine (ICE)
# 3             1368    Petrol  Internal Combustion Engine (ICE)
# 4             1368    Petrol  Internal Combustion Engine (ICE)
#
#    Engine Power (Kw)  Engine Power (PS) Testing Scheme  ...  \
# 0              107.0              145.0           WLTP  ...
# 1              107.0              145.0           WLTP  ...
# 2              107.0              145.0           WLTP  ...
# 3              107.0              145.0           WLTP  ...
# 4              107.0              145.0           WLTP  ...
#
#   Total cost / 10000 miles  Noise Level dB(A)  Emissions CO [mg/km]  \
# 0                   £1,390               73.5                 760.0
# 1                   £1,468               73.5                 760.0
# 2                   £1,390               73.5                 760.0
# 3                   £1,468               73.5                 760.0
# 4                   £1,390               73.5                 760.0
#
#    THC Emissions [mg/km]  Emissions NOx [mg/km]  THC + NOx Emissions [mg/km]  \
# 0                   52.0                   27.0                          NaN
# 1                   52.0                   27.0                          NaN
# 2                   52.0                   27.0                          NaN
# 3                   52.0                   27.0                          NaN
# 4                   52.0                   27.0                          NaN
#
#    Particulates [No.] [mg/km]  RDE NOx Urban  RDE NOx Combined  Unnamed: 45
# 0                         NaN            NaN               NaN          NaN
# 1                         NaN            NaN               NaN          NaN
# 2                         NaN            NaN               NaN          NaN
# 3                         NaN            NaN               NaN          NaN
# 4                         NaN            NaN               NaN          NaN
#
# [5 rows x 46 columns]

# %%
df_d20.groupby(by=df_d20['Fuel Type']).sum()
# Out:
#                       Engine Capacity  Engine Power (Kw)  Engine Power (PS)  \
# Fuel Type
# Diesel                        2625248           167877.0           224726.0
# Diesel Electric                322536            23619.0            32117.0
# Electricity                         0             2460.0             3342.0
# Electricity / Petrol           175998            19541.0            28401.0
# Petrol                        4662287           369190.0           498517.0
# Petrol Electric               1399249            99538.0           137199.0
#
#                       Diesel VED Supplement  \
# Fuel Type
# Diesel                                 1296
# Diesel Electric                           0
# Electricity                               0
# Electricity / Petrol                      0
# Petrol                                    0
# Petrol Electric                           0
#
#                       Electric energy consumption Miles/kWh    wh/km  \
# Fuel Type
# Diesel                                                  0.0      0.0
# Diesel Electric                                         0.0   4998.0
# Electricity                                           149.2   7946.0
# Electricity / Petrol                                  399.8  16775.0
# Petrol                                                  0.0    648.0
# Petrol Electric                                         0.0   8322.0
#
#                       Maximum range (Km)  Maximum range (Miles)  \
# Fuel Type
# Diesel                               0.0                  236.0
# Diesel Electric                   1084.0                    0.0
# Electricity                      14930.0                 9269.0
# Electricity / Petrol              4851.0                 2997.0
# Petrol                             237.0                    0.0
# Petrol Electric                   1584.0                    0.0
#
#                       WLTP Imperial Low  WLTP Imperial Medium  ...  \
# Fuel Type                                                      ...
# Diesel                          50207.3               61039.4  ...
# Diesel Electric                  6628.1                8064.6  ...
# Electricity                         0.0                   0.0  ...
# Electricity / Petrol             2760.6                2829.2  ...
# Petrol                          76837.9              103579.2  ...
# Petrol Electric                 28223.5               34799.1  ...
#
#                       Electric Range City Km  Noise Level dB(A)  \
# Fuel Type
# Diesel                                   0.0            88382.8
# Diesel Electric                          0.0            11816.3
# Electricity                          19261.0             2900.4
# Electricity / Petrol                  3040.0             6353.0
# Petrol                                   0.0           166115.2
# Petrol Electric                          0.0            48141.5
#
#                       Emissions CO [mg/km]  THC Emissions [mg/km]  \
# Fuel Type
# Diesel                            140748.0                12538.0
# Diesel Electric                    40039.0                 2034.0
# Electricity                            0.0                    0.0
# Electricity / Petrol               25666.0                 1152.0
# Petrol                            741485.0                54050.0
# Petrol Electric                   155757.0                13438.0
#
#                       Emissions NOx [mg/km]  THC + NOx Emissions [mg/km]  \
# Fuel Type
# Diesel                              60796.0                      85214.0
# Diesel Electric                      6895.0                      11447.0
# Electricity                             0.0                          0.0
# Electricity / Petrol                 1308.0                        860.0
# Petrol                              48800.0                       8924.0
# Petrol Electric                     10469.0                      14219.0
#
#                       Particulates [No.] [mg/km]  RDE NOx Urban  \
# Fuel Type
# Diesel                                    846.22        79674.0
# Diesel Electric                            72.29         8156.0
# Electricity                                 0.00            0.0
# Electricity / Petrol                        5.75         2402.0
# Petrol                                    836.83       116382.0
# Petrol Electric                            67.98         4726.0
#
#                       RDE NOx Combined  Unnamed: 45
# Fuel Type
# Diesel                         90314.0          0.0
# Diesel Electric                 8116.0          0.0
# Electricity                        0.0          0.0
# Electricity / Petrol            3122.0          0.0
# Petrol                        123560.0          0.0
# Petrol Electric                 4726.0          0.0
#
# [6 rows x 35 columns]

# %% [markdown]
# ## Check whether previous VCA databases have same headers

# %%
#url_d20 was imported above
url_20 = url_d20
url_19 = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/2019/data%20for%20guide%202019.zip'
url_18 = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/sept2018/September%202018%20data%20download.zip'
url_17 = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2017/download-data-for-Aug-2017-Euro-6.zip'
url_16 = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2016/download-data-for-Aug-2016-Euro-6.zip'
url_15a = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2015/download-data-for-Aug-2015-Euro-6.zip'
url_15b = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2015/download-data-for-Aug-2015-Euro-5.zip'
url_14a = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2014/download-data-for-Aug-2014-Euro-6.zip'
url_14b = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2014/download-data-for-Aug-2014-Euro-5.zip'
url_13a = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2013/download-data-for-Aug-2013-Euro-6.zip'
url_13b = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2013/download-data-for-Aug-2013-Euro-6.zip'
url_12a = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2012/download-data-for-Aug-2012-Euro-6.zip'
url_12b = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2012/download-data-for-Aug-2012-Euro-5.zip'
url_12c = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2012/download-data-for-Aug-2012-Euro-4.zip'
url_11a = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2011/download-data-for-Aug-2011-Euro-6.zip'
url_11b = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2011/download-data-for-Aug-2011-Euro-5.zip'
url_11c = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2011/download-data-for-Aug-2011-Euro-4.zip'
url_list = [url_20, url_19, url_18, url_17, url_16, url_15a, url_15b, url_14a, url_14b, url_13a, url_13b, url_12a, url_12b, url_12c, url_11a, url_11b, url_11c]

# %%
url_list[15]
# Out:
# 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2011/download-data-for-Aug-2011-Euro-5.zip'

# %%
df_19 = pd.read_csv(url_19, encoding='cp1252')
df_18 = pd.read_csv(url_18, encoding='cp1252')
df_17 = pd.read_csv(url_17, encoding='cp1252')
df_16 = pd.read_csv(url_16, encoding='cp1252')
df_15a = pd.read_csv(url_15a, encoding='cp1252')
df_15b = pd.read_csv(url_15b, encoding='cp1252')
df_14a = pd.read_csv(url_14a, encoding='cp1252')
df_14b = pd.read_csv(url_14b, encoding='cp1252')
df_13a = pd.read_csv(url_13a, encoding='cp1252')
df_13b = pd.read_csv(url_13b, encoding='cp1252')
df_12a = pd.read_csv(url_12a, encoding='cp1252')
df_12b = pd.read_csv(url_12b, encoding='cp1252')
df_12c = pd.read_csv(url_12c, encoding='cp1252')
# df_11a = pd.read_excel(url_11a)
# df_11b = pd.read_csv(url_11b, encoding='cp1252')
# df_11c = pd.read_csv(url_11c, encoding='cp1252')

# %%
dfs = [df_19, df_18, df_17, df_16, df_15a, df_15b, df_14a, df_14b, df_13a, df_13b, df_12a, df_12b, df_12c]

# %%
# column_header = []
# for df in dfs:
#     print(len(df.columns.tolist()))

# %%
# chs = pd.DataFrame(column_header)

# %%
# chs.head(40)
# Out:
#               0      1            2                   3                  4   \
# 0   Manufacturer  Model  Description        Transmission    Engine Capacity
# 1   Manufacturer  Model  Description        Transmission    Engine Capacity
# 2   Manufacturer  Model  Description        Transmission    Engine Capacity
# 3   Manufacturer  Model  Description        Transmission    Engine Capacity
# 4   Manufacturer  Model  Description        Transmission    Engine Capacity
# 5   Manufacturer  Model  Description        Transmission    Engine Capacity
# 6   Manufacturer  Model  Description  Transmissions Type       Transmission
# 7   Manufacturer  Model  Description        Transmission  Transmission type
# 8   Manufacturer  Model  Description        transmission  Transmission type
# 9   Manufacturer  Model  Description        transmission  Transmission type
# 10  Manufacturer  Model  Description                AorM       Transmission
# 11  Manufacturer  Model  Description                AorM       Transmission
# 12  Manufacturer  Model  Description                AorM       Transmission
#
#                  5                                      6   \
# 0         Fuel Type                      Engine Power (Kw)
# 1         Fuel Type  Electric energy consumption Miles/kWh
# 2         Fuel Type  Electric energy consumption Miles/kWh
# 3         Fuel Type  Electric energy consumption Miles/kWh
# 4         Fuel Type  Electric energy consumption Miles/kWh
# 5         Fuel Type  Electric energy consumption Miles/kWh
# 6   Engine Capacity                              Fuel Type
# 7   Engine Capacity                              Fuel Type
# 8   Engine Capacity                              Fuel Type
# 9   Engine Capacity                              Fuel Type
# 10  Engine Capacity                              Fuel Type
# 11  Engine Capacity                              Fuel Type
# 12  Engine Capacity                              Fuel Type
#
#                                          7                   8   \
# 0                         Engine Power (PS)      Testing Scheme
# 1                                     wh/km  Maximum range (Km)
# 2                                     wh/km  Maximum range (Km)
# 3                                     wh/km  Maximum range (Km)
# 4                                     wh/km  Maximum range (Km)
# 5                                     wh/km  Maximum range (Km)
# 6     Electric energy consumption Miles/kWh               wh/km
# 7     Electric energy consumption Miles/kWh               wh/km
# 8   Electrical energy consumption miles/kWh               wh/km
# 9   Electrical energy consumption miles/kWh               wh/km
# 10                      Metric Urban (Cold)  Metric Extra-Urban
# 11                      Metric Urban (Cold)  Metric Extra-Urban
# 12                      Metric Urban (Cold)  Metric Extra-Urban
#
#                        9   ...                35                        36  \
# 0           Euro Standard  ...  Electricity cost  Total cost / 12000 miles
# 1   Maximum range (Miles)  ...              None                      None
# 2   Maximum range (Miles)  ...              None                      None
# 3   Maximum range (Miles)  ...              None                      None
# 4   Maximum range (Miles)  ...              None                      None
# 5   Maximum range (Miles)  ...       Unnamed: 35               Unnamed: 36
# 6      Maximum range (Km)  ...              None                      None
# 7      Maximum range (Km)  ...       Unnamed: 35               Unnamed: 36
# 8     Electric range (Km)  ...              None                      None
# 9     Electric range (Km)  ...              None                      None
# 10        Metric Combined  ...              None                      None
# 11        Metric Combined  ...              None                      None
# 12        Metric Combined  ...              None                      None
#
#                    37                    38                     39  \
# 0   Noise Level dB(A)  Emissions CO [mg/km]  THC Emissions [mg/km]
# 1                None                  None                   None
# 2                None                  None                   None
# 3                None                  None                   None
# 4                None                  None                   None
# 5                None                  None                   None
# 6                None                  None                   None
# 7         Unnamed: 37           Unnamed: 38            Unnamed: 39
# 8                None                  None                   None
# 9                None                  None                   None
# 10               None                  None                   None
# 11               None                  None                   None
# 12               None                  None                   None
#
#                        40                           41  \
# 0   Emissions NOx [mg/km]  THC + NOx Emissions [mg/km]
# 1                    None                         None
# 2                    None                         None
# 3                    None                         None
# 4                    None                         None
# 5                    None                         None
# 6                    None                         None
# 7             Unnamed: 40                         None
# 8                    None                         None
# 9                    None                         None
# 10                   None                         None
# 11                   None                         None
# 12                   None                         None
#
#                             42             43                44
# 0   Particulates [No.] [mg/km]  RDE NOx Urban  RDE NOx Combined
# 1                         None           None              None
# 2                         None           None              None
# 3                         None           None              None
# 4                         None           None              None
# 5                         None           None              None
# 6                         None           None              None
# 7                         None           None              None
# 8                         None           None              None
# 9                         None           None              None
# 10                        None           None              None
# 11                        None           None              None
# 12                        None           None              None
#
# [13 rows x 45 columns]

# %%
# df_12b.groupby('Fuel Type').sum()

# %%
df_13a[df_13a['Fuel Type'] == 'Electricity'] # This is the earliest df with electric models in
# Out:
#     Manufacturer   Model Description transmission Transmission type  \
# 315   MITSUBISHI  i-MiEV      i-MiEV          NaN               NaN
# 316       NISSAN    Leaf        Leaf          NaN               NaN
#
#      Engine Capacity    Fuel Type  Electrical energy consumption miles/kWh  \
# 315              NaN  Electricity                                      4.6
# 316              NaN  Electricity                                      3.6
#
#      wh/km  Electric range (Km)  ...  Total cost of Driving 12000 miles (£s)  \
# 315  135.0                150.0  ...                                     378
# 316  173.0                175.0  ...                                     484
#
#      Noise Level dB(A)  Emissions CO [mg/km]  THC Emissions [mg/km]  \
# 315               66.0                   NaN                    NaN
# 316               68.0                   NaN                    NaN
#
#      Emissions NOx [mg/km]  THC + NOx Emissions [mg/km]  \
# 315                    NaN                          NaN
# 316                    NaN                          NaN
#
#      Particulates [No.] [mg/km]  Euro Standard      Booklet  VED Band
# 315                         NaN              6  August 2013         A
# 316                         NaN              6  August 2013         A
#
# [2 rows x 30 columns]

# %%
# df_19.groupby('Fuel Type').sum()

# %%
# df_19[df_19['Fuel Type'] == 'Electricity']

# %%
# Creating a master df with all make models & fuel types
columns = ['Manufacturer', 'Model', 'Fuel Type']
df_dict = []
for i in range(0, 12):
    df_dict.append(dfs[i][columns])
master_df = pd.concat(df_dict)
master_df.drop_duplicates(inplace = True)
master_df.shape
# Out:
# (3312, 3)

# %%
master_df.head()
# Out:
#    Manufacturer      Model Fuel Type
# 0        ABARTH        595    Petrol
# 42   ALFA ROMEO     Giulia    Petrol
# 48   ALFA ROMEO     Giulia    Diesel
# 54   ALFA ROMEO  Giulietta    Petrol
# 58   ALFA ROMEO  Giulietta    Diesel

# %%
master_df.groupby('Fuel Type').sum()
# Out:
#                                                                Manufacturer  \
# Fuel Type
# CNG                       VOLKSWAGEN C.V.VOLKSWAGEN C.V.VOLKSWAGEN C.V.V...
# Diesel                    ALFA ROMEOALFA ROMEOALFA ROMEOCHRYSLER JEEPCHR...
# Diesel Electric           KIAMERCEDES-BENZMERCEDES-BENZRENAULTRENAULTMER...
# Diesel/Electric           CITROENPEUGEOTPEUGEOTPEUGEOTMERCEDES-BENZMERCE...
# Electricity               BMWHYUNDAIHYUNDAIJAGUARKIAKIANISSANNISSANNISSA...
# Electricity / Diesel                          AUDIVOLVOVOLVOVOLVOVOLVOVOLVO
# Electricity / Petrol      HYUNDAITOYOTAAUDIBMWBMWBMWBMWBMWBMWBMWKIAKIAKI...
# Petrol                    ABARTHALFA ROMEOALFA ROMEOALFA ROMEOASTON MART...
# Petrol / E85 (Flex Fuel)                                     BENTLEY MOTORS
# Petrol Electric           KIABMWBMWLEXUSMERCEDES-BENZMERCEDES-BENZMERCED...
# Petrol Hybrid             HYUNDAIHYUNDAIKIALEXUSLEXUSLEXUSLEXUSLEXUSLEXU...
# Petrol/E85 (Flex Fuel)                       BENTLEY MOTORSFORDFORDFORDFORD
#
#                                                                       Model
# Fuel Type
# CNG                       Caddy ( Passenger range )Caddy Maxi ( Passenge...
# Diesel                    GiuliaGiuliettaStelvioJeep Compass MY 2019Jeep...
# Diesel Electric           SportageC-Class Estate, Model Year 2018C-Class...
# Diesel/Electric           DS53008508508 RXHE-Class Saloon, Model Year 20...
# Electricity               i Series From November 2013IONIQKonaI-PACE, 19...
# Electricity / Diesel      Q7V60 MY18V60 MY17V60, MY16V60, Model Year 201...
# Electricity / Petrol      IONIQPrius Plug-InA3 Sportbacki Series, From N...
# Petrol                    595GiuliaGiuliettaStelvioDB11 V12 AMR Coupe 20...
# Petrol / E85 (Flex Fuel)                                        Continental
# Petrol Electric           Niro3 Series Saloon F30, From February 20125 S...
# Petrol Hybrid             IONIQKonaNiroCTESISLCLC 500hLC 500h MY19 WLTPL...
# Petrol/E85 (Flex Fuel)    ContinentalFocus Model Year Pre 2012½Galaxy Mo...

# %%
ev_types = master_df[master_df['Fuel Type'] == 'Electricity'].reset_index(drop=True)
ev_types.shape
# Out:
# (40, 3)

# %%
ev_types.head()
# Out:
#   Manufacturer                        Model    Fuel Type
# 0          BMW  i Series From November 2013  Electricity
# 1      HYUNDAI                        IONIQ  Electricity
# 2      HYUNDAI                         Kona  Electricity
# 3       JAGUAR                 I-PACE, 19MY  Electricity
# 4          KIA                      Niro EV  Electricity

# %%
df_av = pd.read_csv('active_vehs.csv')

# %%
df_av.head()
# Out:
#          make      model    num
# 0      TOYOTA      PRIUS  16754
# 1      NISSAN       LEAF  16643
# 2     RENAULT        ZOE   4905
# 3  MITSUBISHI  OUTLANDER   3438
# 4      TOYOTA      AURIS   2702

# %%
master_df = master_df.rename(columns = {'Model': 'model'})
df_try = pd.merge(df_av, master_df, how='left', on='model')

# %%
df_try.head()
# Out:
#          make      model    num Manufacturer Fuel Type
# 0      TOYOTA      PRIUS  16754          NaN       NaN
# 1      NISSAN       LEAF  16643          NaN       NaN
# 2     RENAULT        ZOE   4905          NaN       NaN
# 3  MITSUBISHI  OUTLANDER   3438          NaN       NaN
# 4      TOYOTA      AURIS   2702          NaN       NaN

# %%
df_try.shape
# Out:
# (626, 5)

# %%
df_try.isna().sum()
# Out:
# make              0
# model            97
# num               0
# Manufacturer    580
# Fuel Type       580
# dtype: int64

# %%
df_try_one = df_try.dropna()
df_try_one.head()
# Out:
#           make  model  num Manufacturer             Fuel Type
# 11       LEXUS     CT  962        LEXUS         Petrol Hybrid
# 22     HYUNDAI  IONIQ  260      HYUNDAI           Electricity
# 23     HYUNDAI  IONIQ  260      HYUNDAI         Petrol Hybrid
# 24     HYUNDAI  IONIQ  260      HYUNDAI  Electricity / Petrol
# 27  VOLKSWAGEN     UP  178   VOLKSWAGEN           Electricity

# %% [markdown]
# # Exploring problems in MOT database

# %%
#These are the vehicles listed as 'Electric' in the MOT database
df_av = pd.read_csv('active_vehs.csv')

# %%
df_av.head()
# Out:
#          make      model    num
# 0      TOYOTA      PRIUS  16754
# 1      NISSAN       LEAF  16643
# 2     RENAULT        ZOE   4905
# 3  MITSUBISHI  OUTLANDER   3438
# 4      TOYOTA      AURIS   2702

# %%
mot_model = df_av['make']

# %% [markdown]
# # What does the coronavirus pandemic mean for transport fuel use in the UK?
# Looking at fuel consumption data and coronavirus traffic data

# %%
# Importing packages

# Data importing
import requests
# import odf_py

# Data wrangling and processing
import pandas as pd
import numpy as np

# Data viz
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ### Steps involved:
# 1. Import historic vehicle mileage data, process and clean up
# 2. Import historic vehicle fuel consumption data and clean up
# 3. Explore relationship between miles and fuel
# 4. Import covid traffic data, create prediction for total vehicle miles
# 5. Predict covid effect on petrol & diesel consumption

# %% [markdown]
# ### Step 1) Historic vehicle mileage data

# %% [markdown]
# The Department for Transport (DfT) collects road traffic statistics, and has a historic vehicle mileage data series: table TRA0101.
#
# **Road traffic (vehicle miles) by vehicle type in Great Britain, annual from 1949**

# %%
tra_url = 'https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/916258/tra0101.ods'
vmt = pd.read_excel(tra_url)

# %%
vmt.head(20)
# Out:
#                   Department for Transport statistics Unnamed: 1  \
# 0   Traffic (www.gov.uk/government/organisations/d...        NaN
# 1                                       Table TRA0101        NaN
# 2   Road traffic (vehicle miles) by vehicle type i...        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 5                                                 NaN        NaN
# 6                                                1949        NaN
# 7                                                1950        NaN
# 8                                                1951        NaN
# 9                                                1952        NaN
# 10                                               1953        NaN
# 11                                               1954        NaN
# 12                                               1955        NaN
# 13                                               1956        NaN
# 14                                               1957        NaN
# 15                                               1958        NaN
# 16                                               1959        NaN
# 17                                               1960        NaN
# 18                                               1961        NaN
# 19                                               1962        NaN
#
#         Unnamed: 2                  Unnamed: 3              Unnamed: 4  \
# 0              NaN                         NaN                     NaN
# 1              NaN                         NaN                     NaN
# 2              NaN                         NaN                     NaN
# 3              NaN                         NaN                     NaN
# 4              NaN                         NaN                     NaN
# 5   Cars and Taxis  Light CommercialVehicles 1  Heavy Goods Vehicles 2
# 6             12.6                           4                     7.8
# 7             15.9                         4.8                       7
# 8             18.2                         5.1                     7.3
# 9               19                         5.4                       7
# 10            20.8                         5.7                     7.1
# 11            23.1                         5.8                     7.6
# 12            26.3                         6.1                     8.2
# 13            28.7                         6.2                     8.1
# 14            28.1                         6.4                     7.8
# 15            34.4                         7.4                     8.4
# 16            38.6                         8.5                     9.1
# 17            42.3                         9.3                     9.5
# 18            47.8                        10.2                     9.6
# 19              52                        10.3                     9.6
#
#         Unnamed: 5       Unnamed: 6 Unnamed: 7             Unnamed: 8
# 0              NaN              NaN        NaN                    NaN
# 1              NaN              NaN        NaN                    NaN
# 2              NaN              NaN        NaN                    NaN
# 3              NaN              NaN        NaN  Billion vehicle miles
# 4   Other Vehicles              NaN        NaN                    NaN
# 5      Motorcycles  Buses & Coaches    Total 3     All motor vehicles
# 6              1.9              2.5        4.5                   28.9
# 7              2.7              2.5        5.3                     33
# 8              3.5              2.6        6.1                   36.7
# 9              3.7              2.6        6.3                   37.8
# 10             4.2              2.6        6.8                   40.3
# 11             4.3              2.6        6.9                   43.4
# 12             4.7              2.6        7.3                   47.8
# 13             4.6              2.6        7.2                   50.2
# 14             5.2              2.5        7.6                   49.9
# 15             5.2              2.4        7.6                   57.8
# 16             6.1              2.5        8.6                   64.8
# 17             6.2              2.4        8.6                   69.7
# 18               6              2.5        8.5                   76.1
# 19             5.4              2.5        7.9                   79.8

# %%
# column Unnamed 1 seems to be empty
vmt = vmt.drop(columns = ['Unnamed: 1', 'Unnamed: 7'])

# %% [markdown]
# First, remove some bumpf at the top and bottom of the spreadsheet.

# %%
new_columns = vmt.iloc[5].to_list()

# %%
print((new_columns))
# Out:
# [nan, 'Cars and Taxis', 'Light CommercialVehicles 1', 'Heavy Goods Vehicles 2', 'Motorcycles', 'Buses & Coaches', 'All motor vehicles']

# %%
new_columns = ['year', 'cars', 'lcvs', 'hgvs', 'motorcycles', 'buses_coaches', 'all_motor_vehs']
new_columns = [str.replace(' ', '_') for str in new_columns]

# %%
vmt = vmt[6:].reset_index(drop=True)

# %%
vmt.columns = new_columns

# %%
vmt.head()
# Out:
#    year  cars lcvs hgvs motorcycles buses_coaches all_motor_vehs
# 0  1949  12.6    4  7.8         1.9           2.5           28.9
# 1  1950  15.9  4.8    7         2.7           2.5             33
# 2  1951  18.2  5.1  7.3         3.5           2.6           36.7
# 3  1952    19  5.4    7         3.7           2.6           37.8
# 4  1953  20.8  5.7  7.1         4.2           2.6           40.3

# %% [markdown]
# And now the tail of the dataframe also has bumpf:

# %%
vmt.tail(20)
# Out:
#                                                  year   cars  lcvs  hgvs  \
# 65                                               2014  253.5  46.6  16.2
# 66                                               2015  258.1  48.9  16.8
# 67                                               2016  263.9  51.7    17
# 68                                               2017    269  53.4  17.2
# 69                                               2018  272.3  54.4  17.3
# 70                                               2019  278.2  55.5  17.4
# 71                                                NaN    NaN   NaN   NaN
# 72  1 Not exceeding 3,500 kgs gross vehicle weight...    NaN   NaN   NaN
# 73   2 Over 3,500 kgs gross vehicle weight, post 1982    NaN   NaN   NaN
# 74  3 Total of all other vehicles (i.e. motorcycle...    NaN   NaN   NaN
# 75  4 Data for 1993 onwards are not directly compa...    NaN   NaN   NaN
# 76  R Estimates for the period since 2010 have bee...    NaN   NaN   NaN
# 77  minor road benchmarking exercise. Further deta...    NaN   NaN   NaN
# 78  https://www.gov.uk/government/publications/roa...    NaN   NaN   NaN
# 79                                                NaN    NaN   NaN   NaN
# 80                           Telephone: 020 7944 3095    NaN   NaN   NaN
# 81                  Email: roadtraff.stats@dft.gov.uk    NaN   NaN   NaN
# 82                               Notes & definitions:    NaN   NaN   NaN
# 83  https://www.gov.uk/government/publications/roa...    NaN   NaN   NaN
# 84  The figures in this table are National Statist...    NaN   NaN   NaN
#
#    motorcycles buses_coaches                            all_motor_vehs
# 65         2.9           2.9                                     322.2
# 66         2.9           2.8                                     329.6
# 67           3           2.6                                     338.2
# 68           3           2.6                                     345.2
# 69           3           2.5                                     349.5
# 70           3           2.4                                     356.5
# 71         NaN           NaN                                       NaN
# 72         NaN           NaN  Source: DfT National Road Traffic Survey
# 73         NaN           NaN              Last updated: September 2020
# 74         NaN           NaN                    Next update: June 2021
# 75         NaN           NaN                                       NaN
# 76         NaN           NaN                                       NaN
# 77         NaN           NaN                                       NaN
# 78         NaN           NaN                                       NaN
# 79         NaN           NaN                                       NaN
# 80         NaN           NaN                                       NaN
# 81         NaN           NaN                                       NaN
# 82         NaN           NaN                                       NaN
# 83         NaN           NaN                                       NaN
# 84         NaN           NaN                                       NaN

# %%
vmt = vmt[:71]

# %%
# Make data types numeric
vmt = vmt.astype(float)

# %%
#VMT is now a nice clean dataset, in billions of vehicle miles
vmt.head()
# Out:
#      year  cars  lcvs  hgvs  motorcycles  buses_coaches  all_motor_vehs
# 0  1949.0  12.6   4.0   7.8          1.9            2.5            28.9
# 1  1950.0  15.9   4.8   7.0          2.7            2.5            33.0
# 2  1951.0  18.2   5.1   7.3          3.5            2.6            36.7
# 3  1952.0  19.0   5.4   7.0          3.7            2.6            37.8
# 4  1953.0  20.8   5.7   7.1          4.2            2.6            40.3

# %%
plt.figure(figsize = (15, 5))
sns.lineplot(data=vmt, x='year', y='cars')
sns.lineplot(data=vmt, x='year', y='lcvs')
sns.lineplot(data=vmt, x='year', y='hgvs')
sns.lineplot(data=vmt, x='year', y='motorcycles')
sns.lineplot(data=vmt, x='year', y='buses_coaches')
sns.lineplot(data=vmt, x='year', y='all_motor_vehs')
plt.ylabel('Miles')
plt.xlabel('Year')
plt.title('Vehicle miles travelled, source: DfT')
# Out:
# Text(0.5, 1.0, 'Vehicle miles travelled, source: DfT')

# %% [markdown]
# ### Step 2) Import historic vehicle fuel consumption
# This is available from DfT as table ENV0101.

# %%
fuel_url = 'https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/944684/env0101.ods'
fuel = pd.read_excel(fuel_url)

# %%
# fuel.head(10)

# %%
fuel = fuel.drop(columns=['Department for Transport statistics', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'])

# %%
# fuel.head(20)

# %%
new_columns = fuel.iloc[5].to_list()
new_columns = [str(name).replace('.0', '') for name in new_columns]
new_columns[-1] = '2019'

# %%
# new_columns

# %%
fuel.columns = new_columns
fuel = fuel[6:].reset_index(drop=True)

# %%
# fuel.head(10)

# %%
fuel = fuel.T.reset_index()

# %%
# fuel.head(20)

# %%
new_columns = fuel.iloc[1].to_list()
fuel.columns = new_columns

# %%
fuel = fuel[2:].reset_index(drop=True)

# %%
# fuel.head()

# %%
fuel = fuel.rename(columns={'nan': 'year'})

# %%
fuel = fuel[:29]

# %%
# fuel.tail()

# %%
old_cols = fuel.columns.to_list()
# old_cols

# %%
new_cols_names = ['year', 'petrol_cars', 'petrol_lcvs', 'petrol_motorcycles', 'petrol_total', 'diesel_cars', 'diesel_lcvs', 'diesel_motorcycles', 'diesel_hgvs', 'diesel_total']
new_cols = []
for i in range(len(fuel.columns.to_list())):
    try:
        new_cols.append(new_cols_names[i])
    except:
        new_cols.append('remove')

# %%
print(new_cols)
# Out:
# ['year', 'petrol_cars', 'petrol_lcvs', 'petrol_motorcycles', 'petrol_total', 'diesel_cars', 'diesel_lcvs', 'diesel_motorcycles', 'diesel_hgvs', 'diesel_total', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove', 'remove']

# %%
fuel.columns = new_cols

# %%
# fuel.head()

# %%
fuel = fuel.drop(columns=['remove'])

# %%
# fuel.head()

# %%
# fuel.dtypes

# %%
fuel = fuel.astype(float)

# %%
# fuel.head()

# %%
sns.lineplot(data = fuel, x='year', y='petrol_total')
sns.lineplot(data = fuel, x='year', y='diesel_total')
# Out:
# <AxesSubplot:xlabel='year', ylabel='petrol_total'>

# %% [markdown]
# Let's add a new total column to Fuel. These measures are in millions of tonnes, so we can talk about millions of tonnes of petrol and diesel.

# %%
fuel['total'] = fuel.apply(lambda x: x['petrol_total'] + x['diesel_total'], axis=1)

# %%
sns.lineplot(data = fuel, x='year', y='petrol_total')
sns.lineplot(data = fuel, x='year', y='diesel_total')
sns.lineplot(data=fuel, x='year', y='total')
plt.ylabel('million tonnes fuel')
# Out:
# Text(0, 0.5, 'million tonnes fuel')

# %% [markdown]
# ### Step 3) Explore relationship between mileage and fuel

# %%
vmt.head()
# Out:
#      year  cars  lcvs  hgvs  motorcycles  buses_coaches  all_motor_vehs
# 0  1949.0  12.6   4.0   7.8          1.9            2.5            28.9
# 1  1950.0  15.9   4.8   7.0          2.7            2.5            33.0
# 2  1951.0  18.2   5.1   7.3          3.5            2.6            36.7
# 3  1952.0  19.0   5.4   7.0          3.7            2.6            37.8
# 4  1953.0  20.8   5.7   7.1          4.2            2.6            40.3

# %%
fuel.head()
# Out:
#      year  petrol_cars  petrol_lcvs  petrol_motorcycles  petrol_total  \
# 0  1990.0    21.515020     2.281787            0.236513     24.033321
# 1  1991.0    21.308590     2.210694            0.228796     23.748080
# 2  1992.0    21.504010     2.068771            0.195120     23.767902
# 3  1993.0    21.372669     1.946433            0.165230     23.484332
# 4  1994.0    20.592873     1.796559            0.161219     22.550651
#
#    diesel_cars  diesel_lcvs  diesel_motorcycles  diesel_hgvs  diesel_total  \
# 0     0.985430     1.368665            6.371474     1.641959     10.367528
# 1     1.115129     1.564293            6.057331     1.683803     10.420556
# 2     1.411471     1.750136            6.031653     1.662674     10.855934
# 3     1.806566     1.938817            6.118709     1.659594     11.523686
# 4     2.366744     2.255432            6.313903     1.681598     12.617677
#
#        total
# 0  34.400848
# 1  34.168636
# 2  34.623836
# 3  35.008018
# 4  35.168329

# %% [markdown]
# We have mileage data going back far further than fuel.

# %% [markdown]
# #### Step 3 a) Get data on split between petrol and diesel cars

# %% [markdown]
# And we'll restrict our work to cars from now on...

# %%
# Filter out everything but cars, and create a new sum of fuel consumption by cars
c_fuel = fuel[['year', 'petrol_cars', 'diesel_cars']]
c_fuel['car_total'] = c_fuel.apply(lambda x: x['petrol_cars'] + x['diesel_cars'], axis=1)
# Out:
# <ipython-input-333-57067f2e5c25>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_fuel['car_total'] = c_fuel.apply(lambda x: x['petrol_cars'] + x['diesel_cars'], axis=1)

# %%
# Filter out everything but cars from vmt

# %%
cmt = vmt[['year', 'cars']]

# %% [markdown]
# Now we'll import data on numbers of vehicles. DfT has table veh0203. Licensed cars at the end of the year by propulsion / fuel type, Great Britain from 1994; also United Kingdom from 2014

# %%
num_veh_url = 'https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/882293/veh0203.ods'
vehs = pd.read_excel(num_veh_url)

# %%
vehs.head()
# Out:
#                  Department for Transport statistics Unnamed: 1 Unnamed: 2  \
# 0  Vehicle Licensing Statistics (https://www.gov....        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                     Table VEH0203         NaN        NaN
# 3  Licensed cars at the end of the year by propul...        NaN        NaN
# 4                                                NaN        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9 Unnamed: 10
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN

# %%
new_cols = vehs.iloc[6].to_list()

# %%
vehs = vehs[8:].reset_index(drop=True)

# %%
vehs.columns = new_cols

# %%
# vehs.head()

# %%
vehs = vehs[:26]

# %%
vehs = vehs[['Year', 'Petrol', 'Diesel', 'Total']]

# %%
vehs.head()
# Out:
#    Year     Petrol    Diesel      Total
# 0  1994  19620.898  1576.196  21199.203
# 1  1995  19499.763  1891.271  21394.103
# 2  1996  20051.602  2181.634  22237.538
# 3  1997  20384.711  2440.508  22831.698
# 4  1998  20590.535  2692.904  23293.332

# %%
vehs = vehs.astype(float)

# %%
sns.lineplot(data = vehs, x='Year', y='Petrol')
sns.lineplot(data = vehs, x='Year', y='Diesel')
sns.lineplot(data = vehs, x='Year', y='Total')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Petrol'>

# %%
vehs.head()
# Out:
#      Year     Petrol    Diesel      Total
# 0  1994.0  19620.898  1576.196  21199.203
# 1  1995.0  19499.763  1891.271  21394.103
# 2  1996.0  20051.602  2181.634  22237.538
# 3  1997.0  20384.711  2440.508  22831.698
# 4  1998.0  20590.535  2692.904  23293.332

# %%
cmt.head()
# Out:
#      year  cars
# 0  1949.0  12.6
# 1  1950.0  15.9
# 2  1951.0  18.2
# 3  1952.0  19.0
# 4  1953.0  20.8

# %%
c_fuel.head()
# Out:
#      year  petrol_cars  diesel_cars  car_total
# 0  1990.0    21.515020     0.985430  22.500450
# 1  1991.0    21.308590     1.115129  22.423719
# 2  1992.0    21.504010     1.411471  22.915482
# 3  1993.0    21.372669     1.806566  23.179235
# 4  1994.0    20.592873     2.366744  22.959617

# %% [markdown]
# Let's make all our dataframes start at 1994, since that's the earliest date in `vehs`

# %%
cmt = cmt[cmt['year'] > 1993]

# %%
c_fuel = c_fuel[c_fuel['year'] > 1993]

# %%
df = pd.merge(cmt, c_fuel, how='inner', on='year')

# %%
df.head()
# Out:
#      year   cars  petrol_cars  diesel_cars  car_total
# 0  1994.0  214.4    20.592873     2.366744  22.959617
# 1  1995.0  218.2    19.904986     2.770349  22.675335
# 2  1996.0  223.6    20.434517     3.186620  23.621137
# 3  1997.0  227.3    20.367756     3.489122  23.856878
# 4  1998.0  230.3    20.045429     3.598598  23.644027

# %%
df.dtypes
# Out:
# year           float64
# cars           float64
# petrol_cars    float64
# diesel_cars    float64
# car_total      float64
# dtype: object

# %%
vehs.columns = ['year', 'petrol_car_num', 'diesel_car_num', 'total_car_num']

# %% [markdown]
# ### Step 3.2) Merge our dataframes

# %%
df = pd.merge(df, vehs, how='inner', on='year')

# %%
df.head()
# Out:
#      year   cars  petrol_cars  diesel_cars  car_total  petrol_car_num  \
# 0  1994.0  214.4    20.592873     2.366744  22.959617       19620.898
# 1  1995.0  218.2    19.904986     2.770349  22.675335       19499.763
# 2  1996.0  223.6    20.434517     3.186620  23.621137       20051.602
# 3  1997.0  227.3    20.367756     3.489122  23.856878       20384.711
# 4  1998.0  230.3    20.045429     3.598598  23.644027       20590.535
#
#    diesel_car_num  total_car_num
# 0        1576.196      21199.203
# 1        1891.271      21394.103
# 2        2181.634      22237.538
# 3        2440.508      22831.698
# 4        2692.904      23293.332

# %%
df.columns = ['year',
 'car_miles',
 'petrol_cars_consumption',
 'diesel_cars_consumption',
 'car_total_consumption',
 'petrol_car_num',
 'diesel_car_num',
 'total_car_num']

# %%
df.head()
# Out:
#      year  car_miles  petrol_cars_consumption  diesel_cars_consumption  \
# 0  1994.0      214.4                20.592873                 2.366744
# 1  1995.0      218.2                19.904986                 2.770349
# 2  1996.0      223.6                20.434517                 3.186620
# 3  1997.0      227.3                20.367756                 3.489122
# 4  1998.0      230.3                20.045429                 3.598598
#
#    car_total_consumption  petrol_car_num  diesel_car_num  total_car_num
# 0              22.959617       19620.898        1576.196      21199.203
# 1              22.675335       19499.763        1891.271      21394.103
# 2              23.621137       20051.602        2181.634      22237.538
# 3              23.856878       20384.711        2440.508      22831.698
# 4              23.644027       20590.535        2692.904      23293.332

# %%
df.tail()
# Out:
#       year  car_miles  petrol_cars_consumption  diesel_cars_consumption  \
# 20  2014.0      253.5                11.555919                10.024047
# 21  2015.0      258.1                11.305380                10.439238
# 22  2016.0      263.9                11.165761                10.878597
# 23  2017.0      269.0                11.001546                11.010811
# 24  2018.0      272.3                10.803437                10.819622
#
#     car_total_consumption  petrol_car_num  diesel_car_num  total_car_num
# 20              21.579966       18632.429       10730.906      29611.489
# 21              21.744618       18511.467       11428.857      30250.294
# 22              22.044358       18410.232       12052.146      30850.440
# 23              22.012356       18348.092       12360.237      31200.182
# 24              21.623059       18499.594       12397.636      31517.597

# %%
df.set_index('year')
# Out:
#         car_miles  petrol_cars_consumption  diesel_cars_consumption  \
# year
# 1994.0      214.4                20.592873                 2.366744
# 1995.0      218.2                19.904986                 2.770349
# 1996.0      223.6                20.434517                 3.186620
# 1997.0      227.3                20.367756                 3.489122
# 1998.0      230.3                20.045429                 3.598598
# 1999.0      234.5                20.162464                 3.938916
# 2000.0      233.7                19.924240                 4.111328
# 2001.0      236.9                19.595719                 4.432142
# 2002.0      242.7                19.567260                 4.964760
# 2003.0      242.3                18.752973                 5.406008
# 2004.0      245.0                18.386577                 5.925269
# 2005.0      244.0                17.815770                 6.513523
# 2006.0      246.9                17.062958                 7.122591
# 2007.0      247.3                16.596698                 7.682385
# 2008.0      245.4                15.590061                 8.017552
# 2009.0      244.8                14.730538                 8.175726
# 2010.0      241.9                13.756185                 8.447522
# 2011.0      244.3                13.071047                 8.895104
# 2012.0      245.5                12.451024                 9.426381
# 2013.0      246.6                11.816283                 9.689144
# 2014.0      253.5                11.555919                10.024047
# 2015.0      258.1                11.305380                10.439238
# 2016.0      263.9                11.165761                10.878597
# 2017.0      269.0                11.001546                11.010811
# 2018.0      272.3                10.803437                10.819622
#
#         car_total_consumption  petrol_car_num  diesel_car_num  total_car_num
# year
# 1994.0              22.959617       19620.898        1576.196      21199.203
# 1995.0              22.675335       19499.763        1891.271      21394.103
# 1996.0              23.621137       20051.602        2181.634      22237.538
# 1997.0              23.856878       20384.711        2440.508      22831.698
# 1998.0              23.644027       20590.535        2692.904      23293.332
# 1999.0              24.101380       21031.016        2929.873      23974.937
# 2000.0              24.035568       21232.434        3152.708      24405.549
# 2001.0              24.027861       21640.842        3459.544      25125.867
# 2002.0              24.532020       21839.242        3912.371      25781.931
# 2003.0              24.158981       21805.236        4399.607      26240.404
# 2004.0              24.311846       21976.371        5010.581      27028.099
# 2005.0              24.329293       21875.757        5596.099      27520.398
# 2006.0              24.185549       21465.566        6083.316      27609.171
# 2007.0              24.279083       21264.179        6657.383      28000.264
# 2008.0              23.607613       20898.866        7163.504      28160.702
# 2009.0              22.906264       20490.930        7641.419      28246.470
# 2010.0              22.203707       20082.860        8202.683      28420.877
# 2011.0              21.966151       19548.228        8763.495      28467.289
# 2012.0              21.877405       19158.596        9385.119      28722.453
# 2013.0              21.505427       18870.062       10064.151      29140.937
# 2014.0              21.579966       18632.429       10730.906      29611.489
# 2015.0              21.744618       18511.467       11428.857      30250.294
# 2016.0              22.044358       18410.232       12052.146      30850.440
# 2017.0              22.012356       18348.092       12360.237      31200.182
# 2018.0              21.623059       18499.594       12397.636      31517.597

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Step 3.3) Normalize the data

# %%
from sklearn import preprocessing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-414-d27a4e3c0526> in <module>
# ----> 1 from sklearn import preprocessing
#
# ModuleNotFoundError: No module named 'sklearn'

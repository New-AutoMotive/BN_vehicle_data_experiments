# %% [markdown]
# # Discovering weirdness when trying to gather details about the covid effect on people's mileages...
#
# This is due to people re-using registration numbers...

# %%
import pandas_gbq
from google.oauth2 import service_account
import os
# from google.cloud import bigquery
import tqdm
import seaborn as sns
from matplotlib import pyplot as plt
import datetime as dt
import pandas as pd

# %%
# Credentials for BigQuery
credentials = service_account.Credentials.from_service_account_file('rugged-baton-283921-5706f65c85fe.json')

# %% [markdown]
# This query will find all the MOT tests carried out in March 2021, and extract the list of registration numbers. It will then find the intersection of those registrations and the `mot.vehicles` table, which contains all the vehicle data. We select a random selection of 100 of those vehicles & their tests (by using `ORDER BY rand()` and `LIMT 100`.

# %%
sql = """
WITH registrations as(
    SELECT registration as reg
    FROM `rugged-baton-283921.mots.tests`
    WHERE EXTRACT(YEAR from completedDate) > 2020
    AND EXTRACT(MONTH from completedDate) > 1
    AND testResult = "PASSED"
    GROUP BY registration
), vehicles as (
    SELECT *
    FROM `rugged-baton-283921.mots.vehicles` B
    RIGHT JOIN registrations A
    ON B.registration = A.reg
    WHERE EXTRACT(YEAR from B.firstUsedDate) < 2015
    AND EXTRACT(YEAR from B.firstUsedDate) > 2010
    ORDER BY rand()
    LIMIT 100
) SELECT *
FROM `rugged-baton-283921.mots.tests` A
INNER JOIN vehicles B 
ON A.registration = B.registration
AND A.completedDate > B.firstUsedDate
WHERE A.testResult = "PASSED";
"""

# %%
df = pandas_gbq.read_gbq(sql, project_id='rugged-baton-283921', credentials = credentials, progress_bar_type='tqdm')
# Out:
# Downloading: 100%|████████████████████████████████████████████████████████████████| 349/349 [00:00<00:00, 404.03rows/s]

# %%
# Plot the results of our query, and have a look... 

plt.figure(figsize=(30, 20))
sns.lineplot(data = df, x='completedDate', y='odometerValue', hue='registration', legend=False)
# Out:
# <AxesSubplot:xlabel='completedDate', ylabel='odometerValue'>

# %% [markdown]
# Something has gone **very, very wrong**!!

# %%
#We've got a few too many data points, let's look at those where we have the most records for each individual vehicle...
regs = df.registration.value_counts()[:20].index.to_list()
regs
# Out:
# ['RP04DAN',
#  'M77CHK',
#  'LM54SYD',
#  'BO55ATA',
#  'D12GWP',
#  'S123LMX',
#  'A20MEJ',
#  'RJE8S',
#  'WR07TWO',
#  'M17JDS',
#  'EY14KWG',
#  'MAL667W',
#  'D8EMX',
#  'BE55JME',
#  'Y90STF',
#  'N5CBA',
#  'P444PAU',
#  'B15ENW',
#  'M19CTH',
#  'T77DYL']

# %%
#df2 is a df comprising the 20 vehicles in df which have the most MOT test records. 

df2 = df[df['registration'].isin(regs)]

# %%
plt.figure(figsize=(15, 10))
sns.lineplot(data = df2, x='completedDate', y='odometerValue', hue='registration')
plt.show()
plt.savefig('weirdness.jpg')

# %% [markdown]
# **Gah!!** What on earth is going on? Odometer readings can either plateau, stop, or go up. **They must never go down**

# %%
df2[df2['registration'] == regs[1]].sort_values('completedDate')
# Out:
#                 completedDate testResult                expiryDate  \
# 317 2011-05-12 00:00:00+00:00     PASSED 2012-05-11 00:00:00+00:00
# 316 2012-05-18 00:00:00+00:00     PASSED 2013-05-17 00:00:00+00:00
# 315 2013-05-10 00:00:00+00:00     PASSED 2014-05-17 00:00:00+00:00
# 314 2014-05-20 00:00:00+00:00     PASSED 2015-05-19 00:00:00+00:00
# 313 2015-05-27 00:00:00+00:00     PASSED 2016-05-26 00:00:00+00:00
# 312 2016-05-27 00:00:00+00:00     PASSED 2017-05-26 00:00:00+00:00
# 311 2017-05-20 00:00:00+00:00     PASSED 2018-05-26 00:00:00+00:00
# 310 2018-06-01 00:00:00+00:00     PASSED 2019-05-31 00:00:00+00:00
# 309 2019-06-03 00:00:00+00:00     PASSED 2020-12-02 00:00:00+00:00
# 12  2021-02-13 00:00:00+00:00     PASSED 2022-02-12 00:00:00+00:00
#
#      odometerValue odometerUnit motTestNumber odometerResultType registration  \
# 317          43006           mi  225912531176               READ       M77CHK
# 316          54249           mi  727879432175               READ       M77CHK
# 315          63794           mi  419780633133               READ       M77CHK
# 314          25750           mi  566020844162               READ       M77CHK
# 313          36008           mi  269177845106               READ       M77CHK
# 312          45567           mi  504690126069               READ       M77CHK
# 311          54187           mi  676459395804               READ       M77CHK
# 310          60441           mi  963057766252               READ       M77CHK
# 309          65845           mi  659669757822               READ       M77CHK
# 12           15309           mi  146967628553               READ       M77CHK
#
#         jsonPage registration_1  ... model             firstUsedDate  \
# 317   41117.json         M77CHK  ...  MINI 2011-05-04 00:00:00+00:00
# 316   41117.json         M77CHK  ...  MINI 2011-05-04 00:00:00+00:00
# 315   41117.json         M77CHK  ...  MINI 2011-05-04 00:00:00+00:00
# 314   80158.json         M77CHK  ...  MINI 2011-05-04 00:00:00+00:00
# 313   80158.json         M77CHK  ...  MINI 2011-05-04 00:00:00+00:00
# 312   80158.json         M77CHK  ...  MINI 2011-05-04 00:00:00+00:00
# 311   80158.json         M77CHK  ...  MINI 2011-05-04 00:00:00+00:00
# 310   80158.json         M77CHK  ...  MINI 2011-05-04 00:00:00+00:00
# 309   80158.json         M77CHK  ...  MINI 2011-05-04 00:00:00+00:00
# 12   137882.json         M77CHK  ...  MINI 2011-05-04 00:00:00+00:00
#
#              registrationDate           manufactureDate engineSize  fuelType  \
# 317 2011-05-04 00:00:00+00:00 2011-05-04 00:00:00+00:00     1598.0    Petrol
# 316 2011-05-04 00:00:00+00:00 2011-05-04 00:00:00+00:00     1598.0    Petrol
# 315 2011-05-04 00:00:00+00:00 2011-05-04 00:00:00+00:00     1598.0    Petrol
# 314 2011-05-04 00:00:00+00:00 2011-05-04 00:00:00+00:00     1598.0    Petrol
# 313 2011-05-04 00:00:00+00:00 2011-05-04 00:00:00+00:00     1598.0    Petrol
# 312 2011-05-04 00:00:00+00:00 2011-05-04 00:00:00+00:00     1598.0    Petrol
# 311 2011-05-04 00:00:00+00:00 2011-05-04 00:00:00+00:00     1598.0    Petrol
# 310 2011-05-04 00:00:00+00:00 2011-05-04 00:00:00+00:00     1598.0    Petrol
# 309 2011-05-04 00:00:00+00:00 2011-05-04 00:00:00+00:00     1598.0    Petrol
# 12  2011-05-04 00:00:00+00:00 2011-05-04 00:00:00+00:00     1598.0    Petrol
#
#     primaryColour                 vehicleId  jsonPage_1     reg
# 317         White  6LR_bzLLeao8RfeedJxSzw==  80158.json  M77CHK
# 316         White  6LR_bzLLeao8RfeedJxSzw==  80158.json  M77CHK
# 315         White  6LR_bzLLeao8RfeedJxSzw==  80158.json  M77CHK
# 314         White  6LR_bzLLeao8RfeedJxSzw==  80158.json  M77CHK
# 313         White  6LR_bzLLeao8RfeedJxSzw==  80158.json  M77CHK
# 312         White  6LR_bzLLeao8RfeedJxSzw==  80158.json  M77CHK
# 311         White  6LR_bzLLeao8RfeedJxSzw==  80158.json  M77CHK
# 310         White  6LR_bzLLeao8RfeedJxSzw==  80158.json  M77CHK
# 309         White  6LR_bzLLeao8RfeedJxSzw==  80158.json  M77CHK
# 12          White  6LR_bzLLeao8RfeedJxSzw==  80158.json  M77CHK
#
# [10 rows x 21 columns]

# %% [markdown]
# Turns out the problem is **reused registration numbers**. So when we select a VRN and match it to old MOT test records, we're getting the older vehicle, and all the old vehicle's results, plus the latest new MOT added in, which is making our data... er... problematic.

# %% [markdown]
# ### How to filter out reused registrations
#
# We'll explore the issue of re-used registrations a bit more in notebook number 3. Here, we'll try some quick fixes to our SQL query to see if we can't get rid of them...
#
# Here's our original SQL query, but with a line of code added into the final `WHERE` clause: `AND B.odo >= A.odometerValue`. This filters out any test results that have a lower odometerReading than our latest test result carried out in march.

# %%
sql = """
WITH registrations as(
    SELECT registration as reg, MAX(odometerValue) as odo
    FROM `rugged-baton-283921.mots.tests`
    WHERE EXTRACT(YEAR from completedDate) = 2021
    AND EXTRACT(MONTH from completedDate) > 1
    AND testResult = "PASSED"
    GROUP BY registration
), vehicles as (
    SELECT *
    FROM `rugged-baton-283921.mots.vehicles` B
    RIGHT JOIN registrations A
    ON B.registration = A.reg
    WHERE EXTRACT(YEAR from B.firstUsedDate) < 2015
    AND EXTRACT(YEAR from B.firstUsedDate) > 2010
) SELECT *
FROM `rugged-baton-283921.mots.tests` A
INNER JOIN vehicles B 
ON A.registration = B.registration
AND A.completedDate > B.firstUsedDate
WHERE A.testResult = "PASSED"
AND B.odo >= A.odometerValue;
"""

# %%
df = pandas_gbq.read_gbq(sql, project_id='rugged-baton-283921', credentials = credentials, progress_bar_type='tqdm')
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████| 2900/2900 [00:01<00:00, 2439.70rows/s]

# %%
plt.figure(figsize=(30, 20))
sns.lineplot(data = df, x='completedDate', y='odometerValue', hue='registration', legend=False)
# Out:
# <AxesSubplot:xlabel='completedDate', ylabel='odometerValue'>

# %% [markdown]
# We probably have more vehicles in this dataset than is helpful to try to work with. The graph is a mess, and skewed by one or two other, very problematic odometerValue readings...
#
# Since we just want to sample some vehicles and look for a covid factor, let's take the top 20 vehicles with the most MOT tests to their name.

# %%
regs = df.registration.value_counts()[:20].index.to_list()
regs
# Out:
# ['SL60WLX',
#  'R21UBS',
#  'CA11BWN',
#  'D12GWP',
#  'W21WJJ',
#  'J88OMS',
#  'CP61NHC',
#  'CV12KSU',
#  'R111HJP',
#  'SA61KCX',
#  'RE61MDF',
#  'LN12HKO',
#  'AK62UUA',
#  'YK14XUC',
#  'BA06HAY',
#  'HP53HJP',
#  'AB11LLJ',
#  'LC62CEJ',
#  'K66LEW',
#  'EY14KWG']

# %%
df2 = df[df['registration'].isin(regs)]

# %%
plt.figure(figsize=(30, 20))
sns.lineplot(data = df2, x='completedDate', y='odometerValue', hue='registration', legend=False)
# Out:
# <AxesSubplot:xlabel='completedDate', ylabel='odometerValue'>

# %% [markdown]
# That looks **way better**. Yes, some problematic ones, but mostly the lines do what we'd expect.

# %%
df2.sort_values('completedDate', ascending=False)
# Out:
#                 completedDate testResult                expiryDate  \
# 18  2021-02-24 00:00:00+00:00     PASSED 2022-02-23 00:00:00+00:00
# 19  2021-02-24 00:00:00+00:00     PASSED 2022-02-23 00:00:00+00:00
# 804 2020-07-28 00:00:00+00:00     PASSED 2021-07-27 00:00:00+00:00
# 803 2020-07-28 00:00:00+00:00     PASSED 2021-07-27 00:00:00+00:00
# 951 2020-03-30 00:00:00+00:00     PASSED 2021-03-29 00:00:00+00:00
# ..                        ...        ...                       ...
# 57  2014-05-09 00:00:00+00:00     PASSED 2015-05-08 00:00:00+00:00
# 867 2014-04-15 00:00:00+00:00     PASSED 2015-04-26 00:00:00+00:00
# 866 2014-04-15 00:00:00+00:00     PASSED 2015-04-26 00:00:00+00:00
# 58  2014-01-06 00:00:00+00:00     PASSED 2015-01-05 00:00:00+00:00
# 59  2014-01-06 00:00:00+00:00     PASSED 2015-01-05 00:00:00+00:00
#
#      odometerValue odometerUnit motTestNumber odometerResultType registration  \
# 18           82796           mi  709544342367               READ      EY14KWG
# 19           82796           mi  709544342367               READ      EY14KWG
# 804          72813           mi  486605179514               READ      YK14XUC
# 803          72813           mi  486605179514               READ      YK14XUC
# 951         114156           mi  672110071661               READ      AB11LLJ
# ..             ...          ...           ...                ...          ...
# 57           11737           mi  625939024114               READ      SL60WLX
# 867          14516           mi  447065804181               READ       W21WJJ
# 866          14516           mi  447065804181               READ       W21WJJ
# 58           11315           mi  887496804095               READ      SL60WLX
# 59           11315           mi  887496804095               READ      SL60WLX
#
#         jsonPage registration_1  ...             firstUsedDate  \
# 18   138074.json        EY14KWG  ... 2014-03-05 00:00:00+00:00
# 19   138074.json        EY14KWG  ... 2014-03-05 00:00:00+00:00
# 804  113579.json        YK14XUC  ... 2014-03-07 00:00:00+00:00
# 803  113579.json        YK14XUC  ... 2014-03-07 00:00:00+00:00
# 951  112197.json        AB11LLJ  ... 2013-12-03 00:00:00+00:00
# ..           ...            ...  ...                       ...
# 57    82455.json        SL60WLX  ... 2011-01-05 00:00:00+00:00
# 867   11626.json         W21WJJ  ... 2011-04-26 00:00:00+00:00
# 866   11626.json         W21WJJ  ... 2011-04-26 00:00:00+00:00
# 58    82455.json        SL60WLX  ... 2011-01-05 00:00:00+00:00
# 59    82455.json        SL60WLX  ... 2011-01-05 00:00:00+00:00
#
#              registrationDate           manufactureDate engineSize fuelType  \
# 18  2014-03-05 00:00:00+00:00 2014-03-05 00:00:00+00:00     2993.0   Diesel
# 19  2014-03-05 00:00:00+00:00 2014-03-05 00:00:00+00:00     2993.0   Diesel
# 804 2014-03-07 00:00:00+00:00 2014-03-07 00:00:00+00:00     1686.0   Diesel
# 803 2014-03-07 00:00:00+00:00 2014-03-07 00:00:00+00:00     1700.0   Diesel
# 951 2013-12-03 00:00:00+00:00 2013-12-03 00:00:00+00:00     1598.0   Diesel
# ..                        ...                       ...        ...      ...
# 57  2011-01-05 00:00:00+00:00 2011-01-05 00:00:00+00:00     1560.0   Diesel
# 867 2011-04-26 00:00:00+00:00 2011-04-26 00:00:00+00:00     1388.0   Petrol
# 866 2011-04-26 00:00:00+00:00 2011-04-26 00:00:00+00:00     1388.0   Petrol
# 58  2011-01-05 00:00:00+00:00 2011-01-05 00:00:00+00:00     1560.0   Diesel
# 59  2011-01-05 00:00:00+00:00 2011-01-05 00:00:00+00:00     1560.0   Diesel
#
#      primaryColour                 vehicleId   jsonPage_1      reg     odo
# 18            Grey  E_B5ZL7pVIRgf2Icb-Sm2g==  138074.json  EY14KWG   82797
# 19            Grey  W6JrpDEX8-BiTDbNQEdDuA==  113679.json  EY14KWG   82797
# 804          White  Q4xQSilHbfnXT1q6_S5m6Q==  113579.json  YK14XUC   73993
# 803          White  rqffq4S_9UnbKXzuD1jRYQ==  138253.json  YK14XUC   73993
# 951           Blue  WlJSs5oPhrqzkgO5N8zKNg==  138284.json  AB11LLJ  121822
# ..             ...                       ...          ...      ...     ...
# 57            Grey  -_vV56oQi4RVMOW6I4Zvhg==   82455.json  SL60WLX   86493
# 867           Blue  sMAWJNFaisY_FqCzOtuHOA==   11626.json   W21WJJ   49854
# 866           Blue  G3-TvoWy8UdKbdcje_ErFw==  138091.json   W21WJJ   49854
# 58            Grey  AYBItv6ulizkErs_sq5Zmw==  137938.json  SL60WLX   86493
# 59            Grey  -_vV56oQi4RVMOW6I4Zvhg==   82455.json  SL60WLX   86493
#
# [230 rows x 22 columns]

# %% [markdown]
# ### Now to measure *change* in annual mileage. For every registration, we need to measure how many additional miles are being driven in the period between each test.
#
# Let's start by simplifying things and getting rid of some values that we don't really need.

# %%
# We can come back to df3 to look at makes/models, etc. 
df3 = df2[['completedDate', 'odometerValue', 'registration', 'fuelType', 'make', 'primaryColour']]

# %%
# df_g is a grouped dataframe
df_g = df3.groupby(['registration', 'completedDate']).mean()
df_g.reset_index(inplace=True)
df_g.set_index(['registration'])
# df_g.head(15)
# Out:
#                          completedDate  odometerValue
# registration
# AB11LLJ      2016-11-07 00:00:00+00:00          73112
# AB11LLJ      2017-03-15 00:00:00+00:00          78068
# AB11LLJ      2018-03-13 00:00:00+00:00          91482
# AB11LLJ      2019-03-13 00:00:00+00:00         103783
# AB11LLJ      2020-03-30 00:00:00+00:00         114156
# ...                                ...            ...
# YK14XUC      2018-02-23 00:00:00+00:00          54068
# YK14XUC      2019-03-05 00:00:00+00:00          58903
# YK14XUC      2020-02-21 00:00:00+00:00          70244
# YK14XUC      2020-07-28 00:00:00+00:00          72813
# YK14XUC      2021-03-04 00:00:00+00:00          73993
#
# [134 rows x 2 columns]

# %%
df_g['time_diff'] = df_g.groupby(['registration'])['completedDate'].diff()

# %%
df_g['mile_diff'] = df_g.groupby(['registration'])['odometerValue'].diff()

# %%
df_g.head(20)
# Out:
#    registration             completedDate  odometerValue time_diff  mile_diff
# 0       AB11LLJ 2016-11-07 00:00:00+00:00          73112       NaT        NaN
# 1       AB11LLJ 2017-03-15 00:00:00+00:00          78068  128 days     4956.0
# 2       AB11LLJ 2018-03-13 00:00:00+00:00          91482  363 days    13414.0
# 3       AB11LLJ 2019-03-13 00:00:00+00:00         103783  365 days    12301.0
# 4       AB11LLJ 2020-03-30 00:00:00+00:00         114156  383 days    10373.0
# 5       AB11LLJ 2021-03-05 00:00:00+00:00         121822  340 days     7666.0
# 6       AK62UUA 2015-08-05 00:00:00+00:00          21066       NaT        NaN
# 7       AK62UUA 2016-08-13 00:00:00+00:00          25253  374 days     4187.0
# 8       AK62UUA 2017-08-07 00:00:00+00:00          29994  359 days     4741.0
# 9       AK62UUA 2018-05-19 00:00:00+00:00          31946  285 days     1952.0
# 10      AK62UUA 2019-05-21 00:00:00+00:00          38956  367 days     7010.0
# 11      AK62UUA 2021-02-12 00:00:00+00:00          60600  633 days    21644.0
# 12      BA06HAY 2014-11-14 00:00:00+00:00          36378       NaT        NaN
# 13      BA06HAY 2015-11-14 00:00:00+00:00          48474  365 days    12096.0
# 14      BA06HAY 2016-11-28 00:00:00+00:00          61390  380 days    12916.0
# 15      BA06HAY 2018-06-20 00:00:00+00:00          71939  569 days    10549.0
# 16      BA06HAY 2019-07-01 00:00:00+00:00          79508  376 days     7569.0
# 17      BA06HAY 2021-02-23 00:00:00+00:00          92886  603 days    13378.0
# 18      CA11BWN 2015-01-05 00:00:00+00:00          29272       NaT        NaN
# 19      CA11BWN 2015-12-18 00:00:00+00:00          41167  347 days    11895.0

# %%
df_no_na = df_g.dropna()
df_no_na.head()
# Out:
#   registration             completedDate  odometerValue time_diff  mile_diff
# 1      AB11LLJ 2017-03-15 00:00:00+00:00          78068  128 days     4956.0
# 2      AB11LLJ 2018-03-13 00:00:00+00:00          91482  363 days    13414.0
# 3      AB11LLJ 2019-03-13 00:00:00+00:00         103783  365 days    12301.0
# 4      AB11LLJ 2020-03-30 00:00:00+00:00         114156  383 days    10373.0
# 5      AB11LLJ 2021-03-05 00:00:00+00:00         121822  340 days     7666.0

# %%
df_no_na['secs_diff'] = pd.total_second(df_no_na['time_diff'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-f478c1b222f2> in <module>
# ----> 1 df_no_na['secs_diff'] = pd.total_second(df_no_na['time_diff'])
#
# NameError: name 'pd' is not defined

# %%
df_no_na['avg_ann'] = (df_no_na['mile_diff'] / df_no_na['time_diff'])*365
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-62162a1bc247> in <module>
# ----> 1 df_no_na['avg_ann'] = (df_no_na['mile_diff'] / df_no_na['time_diff'])*365
#
# ~\.conda\envs\mot\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\.conda\envs\mot\lib\site-packages\pandas\core\arraylike.py in __truediv__(self, other)
#     111     @unpack_zerodim_and_defer("__truediv__")
#     112     def __truediv__(self, other):
# --> 113         return self._arith_method(other, operator.truediv)
#     114
#     115     @unpack_zerodim_and_defer("__rtruediv__")
#
# ~\.conda\envs\mot\lib\site-packages\pandas\core\series.py in _arith_method(self, other, op)
#    4993         lvalues = extract_array(self, extract_numpy=True)
#    4994         rvalues = extract_array(other, extract_numpy=True)
# -> 4995         result = ops.arithmetic_op(lvalues, rvalues, op)
#    4996
#    4997         return self._construct_result(result, name=res_name)
#
# ~\.conda\envs\mot\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     183     if should_extension_dispatch(lvalues, rvalues) or isinstance(rvalues, Timedelta):
#     184         # Timedelta is included because numexpr will fail on it, see GH#31457
# --> 185         res_values = op(lvalues, rvalues)
#     186
#     187     else:
#
# ~\.conda\envs\mot\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\.conda\envs\mot\lib\site-packages\pandas\core\arrays\timedeltas.py in __rtruediv__(self, other)
#     606
#     607         else:
# --> 608             raise TypeError(
#     609                 f"Cannot divide {other.dtype} data by {type(self).__name__}"
#     610             )
#
# TypeError: Cannot divide float64 data by TimedeltaArray

# %%
df3.drop_duplicates(keep = 'first', inplace=True)
df3 = df3.sort_values(by=['registration', 'completedDate'])
df3['diff'] = df3.groupby(['registration', 'make', 'fuelType', 'primaryColour', 'completedDate'])['odometerValue'].diff()
# Out:
# <ipython-input-66-243cb773fcc8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop_duplicates(keep = 'first', inplace=True)

# %%
df3.drop_duplicates(keep='first', inplace=True)
df3.head(20)
# Out:
#                  completedDate  odometerValue registration fuelType  \
# 2448 2016-11-07 00:00:00+00:00          73112      AB11LLJ   Diesel
# 2449 2016-11-07 00:00:00+00:00          73112      AB11LLJ   Diesel
# 2446 2017-03-15 00:00:00+00:00          78068      AB11LLJ   Diesel
# 2447 2017-03-15 00:00:00+00:00          78068      AB11LLJ   Diesel
# 2452 2018-03-13 00:00:00+00:00          91482      AB11LLJ   Diesel
# 2453 2018-03-13 00:00:00+00:00          91482      AB11LLJ   Diesel
# 2450 2019-03-13 00:00:00+00:00         103783      AB11LLJ   Diesel
# 2451 2019-03-13 00:00:00+00:00         103783      AB11LLJ   Diesel
# 2454 2020-03-30 00:00:00+00:00         114156      AB11LLJ   Diesel
# 2455 2020-03-30 00:00:00+00:00         114156      AB11LLJ   Diesel
# 287  2021-03-05 00:00:00+00:00         121822      AB11LLJ   Diesel
# 288  2021-03-05 00:00:00+00:00         121822      AB11LLJ   Diesel
# 2374 2015-08-05 00:00:00+00:00          21066      AK62UUA   Diesel
# 2375 2015-08-05 00:00:00+00:00          21066      AK62UUA   Diesel
# 2372 2016-08-13 00:00:00+00:00          25253      AK62UUA   Diesel
# 2373 2016-08-13 00:00:00+00:00          25253      AK62UUA   Diesel
# 2370 2017-08-07 00:00:00+00:00          29994      AK62UUA   Diesel
# 2371 2017-08-07 00:00:00+00:00          29994      AK62UUA   Diesel
# 2368 2018-05-19 00:00:00+00:00          31946      AK62UUA   Diesel
# 2369 2018-05-19 00:00:00+00:00          31946      AK62UUA   Diesel
#
#             make primaryColour  diff
# 2448        AUDI          Blue   NaN
# 2449        AUDI          Blue   0.0
# 2446        AUDI          Blue   NaN
# 2447        AUDI          Blue   0.0
# 2452        AUDI          Blue   NaN
# 2453        AUDI          Blue   0.0
# 2450        AUDI          Blue   NaN
# 2451        AUDI          Blue   0.0
# 2454        AUDI          Blue   NaN
# 2455        AUDI          Blue   0.0
# 287         AUDI          Blue   NaN
# 288         AUDI          Blue   0.0
# 2374  VOLKSWAGEN         Black   NaN
# 2375  VOLKSWAGEN         Black   0.0
# 2372  VOLKSWAGEN         Black   NaN
# 2373  VOLKSWAGEN         Black   0.0
# 2370  VOLKSWAGEN         Black   NaN
# 2371  VOLKSWAGEN         Black   0.0
# 2368  VOLKSWAGEN         Black   NaN
# 2369  VOLKSWAGEN         Black   0.0

# %%
plt.figure(figsize=(30, 20))
sns.lineplot(data = df2, x='completedDate', y='odometerValue', hue='registration', legend=False)

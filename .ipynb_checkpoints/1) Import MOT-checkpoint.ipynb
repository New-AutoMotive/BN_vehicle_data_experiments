# %%
import pandas_gbq
from google.oauth2 import service_account
import os
# from google.cloud import bigquery
import tqdm
import seaborn as sns
from matplotlib import pyplot as plt
import datetime as dt

# %%
# os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'rugged-baton-283921-5706f65c85fe.json'
credentials = service_account.Credentials.from_service_account_file('rugged-baton-283921-5706f65c85fe.json')

# %%
# bigquery_client = bigquery.Client()

# %%
# bigquery_client

# %%
# query='''
# SELECT *
# FROM `rugged-baton-283921.mots.vehicles_202101`
# WHERE (EXTRACT(YEAR FROM firstUsedDate)) > 1995
# AND EXTRACT(YEAR FROM firstUsedDate) < 2010
# ORDER BY rand()
# LIMIT 3000000;
# '''

# %%
# query_job = bigquery_client.query(query)

# %%
sql = """
WITH vehicles as (
    SELECT *
    FROM `rugged-baton-283921.mots.vehicles_202101`
    WHERE EXTRACT(YEAR from registrationDate) > 2005
    AND EXTRACT(YEAR from registrationDate) < 2007
    ORDER BY rand() 
    LIMIT 100
) SELECT *
FROM `rugged-baton-283921.mots.tests_202101` A
INNER JOIN vehicles B 
ON A.registration = B.registration
WHERE A.testResult = "PASSED";

"""

# %%
df = pandas_gbq.read_gbq(sql, project_id='rugged-baton-283921', credentials = credentials, progress_bar_type='tqdm')
# Out:
# Downloading: 100%|████████████████████████████████████████████████████████████████| 945/945 [00:01<00:00, 913.35rows/s]

# %%
df.head()
# Out:
#               completedDate testResult                expiryDate  \
# 0 2020-05-20 00:00:00+00:00     PASSED 2021-06-01 00:00:00+00:00
# 1 2019-05-31 00:00:00+00:00     PASSED 2020-06-01 00:00:00+00:00
# 2 2018-06-02 00:00:00+00:00     PASSED 2019-06-01 00:00:00+00:00
# 3 2017-06-01 00:00:00+00:00     PASSED 2018-05-31 00:00:00+00:00
# 4 2016-04-04 00:00:00+00:00     PASSED 2017-04-20 00:00:00+00:00
#
#    odometerValue odometerUnit motTestNumber odometerResultType registration  \
# 0          11061           mi  268695881711               READ      AY06DSZ
# 1          11004           mi  434764599544               READ      AY06DSZ
# 2          10746           mi  971414934877               READ      AY06DSZ
# 3          10361           mi  365652881626               READ      AY06DSZ
# 4           9823           mi  488587492324               READ      AY06DSZ
#
#     jsonPage registration_1             make  model             firstUsedDate  \
# 0  1425.json        AY06DSZ  HARLEY-DAVIDSON  FXDBI 2006-05-16 00:00:00+00:00
# 1  1425.json        AY06DSZ  HARLEY-DAVIDSON  FXDBI 2006-05-16 00:00:00+00:00
# 2  1425.json        AY06DSZ  HARLEY-DAVIDSON  FXDBI 2006-05-16 00:00:00+00:00
# 3  1425.json        AY06DSZ  HARLEY-DAVIDSON  FXDBI 2006-05-16 00:00:00+00:00
# 4  1425.json        AY06DSZ  HARLEY-DAVIDSON  FXDBI 2006-05-16 00:00:00+00:00
#
#            registrationDate           manufactureDate  engineSize fuelType  \
# 0 2006-05-16 00:00:00+00:00 2006-05-16 00:00:00+00:00      1449.0   Petrol
# 1 2006-05-16 00:00:00+00:00 2006-05-16 00:00:00+00:00      1449.0   Petrol
# 2 2006-05-16 00:00:00+00:00 2006-05-16 00:00:00+00:00      1449.0   Petrol
# 3 2006-05-16 00:00:00+00:00 2006-05-16 00:00:00+00:00      1449.0   Petrol
# 4 2006-05-16 00:00:00+00:00 2006-05-16 00:00:00+00:00      1449.0   Petrol
#
#   primaryColour                 vehicleId jsonPage_1
# 0         Black  Ju_97wWLpU1APuNg40Q09w==  1425.json
# 1         Black  Ju_97wWLpU1APuNg40Q09w==  1425.json
# 2         Black  Ju_97wWLpU1APuNg40Q09w==  1425.json
# 3         Black  Ju_97wWLpU1APuNg40Q09w==  1425.json
# 4         Black  Ju_97wWLpU1APuNg40Q09w==  1425.json

# %%
unique_vrms = df['registration'].unique().tolist()

# %%
len(unique_vrms)
# Out:
# 100

# %%
unique_vrms[45]
# Out:
# 'YH56VGD'

# %%
df.drop(df[df['registration'] == 'FL56MHK'].index, inplace=True)

# %%
eg_df = df[df['registration'] == 'FL56MHK']
eg_df.head(30)
# Out:
# Empty DataFrame
# Columns: [completedDate, testResult, expiryDate, odometerValue, odometerUnit, motTestNumber, odometerResultType, registration, jsonPage, registration_1, make, model, firstUsedDate, registrationDate, manufactureDate, engineSize, fuelType, primaryColour, vehicleId, jsonPage_1]
# Index: []

# %%
data = df[df['fuelType'] == 'Diesel']

plt.figure(figsize = (20, 30))
sns.lineplot(data = data, x = 'completedDate', y='odometerValue', hue='registration')
# Out:
# <AxesSubplot:xlabel='completedDate', ylabel='odometerValue'>

# %%
# Out:
#        odometerValue   engineSize
# count     945.000000   943.000000
# mean    67415.416931  1685.870626
# std     49217.786555   457.801905
# min         0.000000   124.000000
# 25%     36848.000000  1368.000000
# 50%     61034.000000  1598.000000
# 75%     89739.000000  1975.000000
# max    952827.000000  2987.000000

# %%
first_year = df[df['completedDate'] < '2010']
first_year.head()
# Out:
#                completedDate testResult                expiryDate  \
# 11 2009-04-22 00:00:00+00:00     PASSED 2010-05-16 00:00:00+00:00
# 22 2009-09-08 00:00:00+00:00     PASSED 2010-09-07 00:00:00+00:00
# 38 2009-06-18 00:00:00+00:00     PASSED 2010-06-17 00:00:00+00:00
# 39 2009-03-06 00:00:00+00:00     PASSED 2010-03-09 00:00:00+00:00
# 52 2009-05-26 00:00:00+00:00     PASSED 2010-05-26 00:00:00+00:00
#
#     odometerValue odometerUnit motTestNumber odometerResultType registration  \
# 11           6436           mi  662662319175               READ      AY06DSZ
# 22          74295           mi  412681559287               READ      PJ56RCF
# 38          41686           mi  871959669114               READ      BN06DVH
# 39          40242           mi  592215969080               READ      BN06DVH
# 52          13943           mi  632126449179               READ      AJ06YGO
#
#       jsonPage registration_1             make   model  \
# 11   1425.json        AY06DSZ  HARLEY-DAVIDSON   FXDBI
# 22  51032.json        PJ56RCF          PEUGEOT     206
# 38   6892.json        BN06DVH             FORD  FIESTA
# 39   6892.json        BN06DVH             FORD  FIESTA
# 52   1843.json        AJ06YGO             FIAT   PUNTO
#
#                firstUsedDate          registrationDate  \
# 11 2006-05-16 00:00:00+00:00 2006-05-16 00:00:00+00:00
# 22 2006-12-15 00:00:00+00:00 2006-12-15 00:00:00+00:00
# 38 2006-03-09 00:00:00+00:00 2006-03-09 00:00:00+00:00
# 39 2006-03-09 00:00:00+00:00 2006-03-09 00:00:00+00:00
# 52 2006-05-26 00:00:00+00:00 2006-05-26 00:00:00+00:00
#
#              manufactureDate  engineSize fuelType primaryColour  \
# 11 2006-05-16 00:00:00+00:00      1449.0   Petrol         Black
# 22 2006-12-15 00:00:00+00:00      1560.0   Petrol          Grey
# 38 2006-03-09 00:00:00+00:00      1399.0   Diesel         White
# 39 2006-03-09 00:00:00+00:00      1399.0   Diesel         White
# 52 2006-05-26 00:00:00+00:00      1242.0   Petrol          Grey
#
#                    vehicleId  jsonPage_1
# 11  Ju_97wWLpU1APuNg40Q09w==   1425.json
# 22  I_88Prj3p-pU9zJVqlaC7A==  51032.json
# 38  Dv4kQRFCJy1eM192rIYZMw==   6892.json
# 39  Dv4kQRFCJy1eM192rIYZMw==   6892.json
# 52  Xo6mOYjSS04k7ymckiQmdg==   1843.json

# %%
df['year_mot'] = df['completedDate'].dt.year

# %%
df.head()
# Out:
#               completedDate testResult                expiryDate  \
# 0 2020-05-20 00:00:00+00:00     PASSED 2021-06-01 00:00:00+00:00
# 1 2019-05-31 00:00:00+00:00     PASSED 2020-06-01 00:00:00+00:00
# 2 2018-06-02 00:00:00+00:00     PASSED 2019-06-01 00:00:00+00:00
# 3 2017-06-01 00:00:00+00:00     PASSED 2018-05-31 00:00:00+00:00
# 4 2016-04-04 00:00:00+00:00     PASSED 2017-04-20 00:00:00+00:00
#
#    odometerValue odometerUnit motTestNumber odometerResultType registration  \
# 0          11061           mi  268695881711               READ      AY06DSZ
# 1          11004           mi  434764599544               READ      AY06DSZ
# 2          10746           mi  971414934877               READ      AY06DSZ
# 3          10361           mi  365652881626               READ      AY06DSZ
# 4           9823           mi  488587492324               READ      AY06DSZ
#
#     jsonPage registration_1  ...  model             firstUsedDate  \
# 0  1425.json        AY06DSZ  ...  FXDBI 2006-05-16 00:00:00+00:00
# 1  1425.json        AY06DSZ  ...  FXDBI 2006-05-16 00:00:00+00:00
# 2  1425.json        AY06DSZ  ...  FXDBI 2006-05-16 00:00:00+00:00
# 3  1425.json        AY06DSZ  ...  FXDBI 2006-05-16 00:00:00+00:00
# 4  1425.json        AY06DSZ  ...  FXDBI 2006-05-16 00:00:00+00:00
#
#            registrationDate           manufactureDate engineSize  fuelType  \
# 0 2006-05-16 00:00:00+00:00 2006-05-16 00:00:00+00:00     1449.0    Petrol
# 1 2006-05-16 00:00:00+00:00 2006-05-16 00:00:00+00:00     1449.0    Petrol
# 2 2006-05-16 00:00:00+00:00 2006-05-16 00:00:00+00:00     1449.0    Petrol
# 3 2006-05-16 00:00:00+00:00 2006-05-16 00:00:00+00:00     1449.0    Petrol
# 4 2006-05-16 00:00:00+00:00 2006-05-16 00:00:00+00:00     1449.0    Petrol
#
#   primaryColour                 vehicleId jsonPage_1 year_mot
# 0         Black  Ju_97wWLpU1APuNg40Q09w==  1425.json     2020
# 1         Black  Ju_97wWLpU1APuNg40Q09w==  1425.json     2019
# 2         Black  Ju_97wWLpU1APuNg40Q09w==  1425.json     2018
# 3         Black  Ju_97wWLpU1APuNg40Q09w==  1425.json     2017
# 4         Black  Ju_97wWLpU1APuNg40Q09w==  1425.json     2016
#
# [5 rows x 21 columns]

# %%
petrol_diesel = df.groupby(['fuelType', 'year_mot']).sum()
petrol_diesel.head()
# Out:
#                    odometerValue  engineSize
# fuelType year_mot
# Diesel   2009            2079035     87822.0
#          2010            2174575     77279.0
#          2011            2233928     73819.0
#          2012            2783560     76996.0
#          2013            3210252     79678.0

# %%
sns.lineplot(data = petrol_diesel, x = 'year_mot', y='odometerValue', hue='fuelType')
# Out:
# <AxesSubplot:xlabel='year_mot', ylabel='odometerValue'>

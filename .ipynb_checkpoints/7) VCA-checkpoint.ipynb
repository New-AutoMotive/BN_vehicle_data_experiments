# %% [markdown]
# # Using VCA data to identify BEVs

# %% [markdown]
# We're going to try to use the VCA database to see whether we can identify:
# 1. vehicles that are BEV/PHEV/PETROL/DIESEL in veh0120, and
# 2. vehicles that are BEV/PHEV/PETROL/DIESEL in latest vehicle mileage estimates in our database

# %% [markdown]
# To test whether this is possible, we'll start by exploring some of the VCA data on emissions & vehicle types

# %%
#import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from zipfile import ZipFile

# %%
#First we'll import the latest 2020 vehicle emissions data
url_d20 = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/2020/data%20for%20guide%202020.zip'
df_d20 = pd.read_csv(url_d20, encoding='cp1252')

# %%
df_d20.head()
# Out:
#   Manufacturer Model                       Description Transmission  \
# 0       ABARTH   595                   595 1.4 145 BHP           M5
# 1       ABARTH   595                  595 1.4 145 BHP            M5
# 2       ABARTH   595              595 1.4 TJET 145 BHP           M5
# 3       ABARTH   595             595 1.4 TJET 145 BHP            M5
# 4       ABARTH   595  595 1.4 TJET 145 BHP Convertible           M5
#
#    Engine Capacity Fuel Type                        Powertrain  \
# 0             1368    Petrol  Internal Combustion Engine (ICE)
# 1             1368    Petrol  Internal Combustion Engine (ICE)
# 2             1368    Petrol  Internal Combustion Engine (ICE)
# 3             1368    Petrol  Internal Combustion Engine (ICE)
# 4             1368    Petrol  Internal Combustion Engine (ICE)
#
#    Engine Power (Kw)  Engine Power (PS) Testing Scheme  ...  \
# 0              107.0              145.0           WLTP  ...
# 1              107.0              145.0           WLTP  ...
# 2              107.0              145.0           WLTP  ...
# 3              107.0              145.0           WLTP  ...
# 4              107.0              145.0           WLTP  ...
#
#   Total cost / 10000 miles  Noise Level dB(A)  Emissions CO [mg/km]  \
# 0                   £1,390               73.5                 760.0
# 1                   £1,468               73.5                 760.0
# 2                   £1,390               73.5                 760.0
# 3                   £1,468               73.5                 760.0
# 4                   £1,390               73.5                 760.0
#
#    THC Emissions [mg/km]  Emissions NOx [mg/km]  THC + NOx Emissions [mg/km]  \
# 0                   52.0                   27.0                          NaN
# 1                   52.0                   27.0                          NaN
# 2                   52.0                   27.0                          NaN
# 3                   52.0                   27.0                          NaN
# 4                   52.0                   27.0                          NaN
#
#    Particulates [No.] [mg/km]  RDE NOx Urban  RDE NOx Combined  Unnamed: 45
# 0                         NaN            NaN               NaN          NaN
# 1                         NaN            NaN               NaN          NaN
# 2                         NaN            NaN               NaN          NaN
# 3                         NaN            NaN               NaN          NaN
# 4                         NaN            NaN               NaN          NaN
#
# [5 rows x 46 columns]

# %%
df_d20.groupby(by=df_d20['Powertrain']).sum()
# Out:
#                                                     Engine Capacity  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...                0
# Hybrid Electric Vehicle (HEV)                               1721785
# Internal Combustion Engine (ICE)                            7287535
# Plug-in Hybrid Electric Vehicle (PHEV)                       175998
#
#                                                     Engine Power (Kw)  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...             2460.0
# Hybrid Electric Vehicle (HEV)                                123157.0
# Internal Combustion Engine (ICE)                             537067.0
# Plug-in Hybrid Electric Vehicle (PHEV)                        19541.0
#
#                                                     Engine Power (PS)  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...             3342.0
# Hybrid Electric Vehicle (HEV)                                169316.0
# Internal Combustion Engine (ICE)                             723243.0
# Plug-in Hybrid Electric Vehicle (PHEV)                        28401.0
#
#                                                     Diesel VED Supplement  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...                      0
# Hybrid Electric Vehicle (HEV)                                           0
# Internal Combustion Engine (ICE)                                     1296
# Plug-in Hybrid Electric Vehicle (PHEV)                                  0
#
#                                                     Electric energy consumption Miles/kWh  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...                                  149.2
# Hybrid Electric Vehicle (HEV)                                                         0.0
# Internal Combustion Engine (ICE)                                                      0.0
# Plug-in Hybrid Electric Vehicle (PHEV)                                              399.8
#
#                                                       wh/km  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...   7946.0
# Hybrid Electric Vehicle (HEV)                       13320.0
# Internal Combustion Engine (ICE)                      648.0
# Plug-in Hybrid Electric Vehicle (PHEV)              16775.0
#
#                                                     Maximum range (Km)  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...             14930.0
# Hybrid Electric Vehicle (HEV)                                   2668.0
# Internal Combustion Engine (ICE)                                 237.0
# Plug-in Hybrid Electric Vehicle (PHEV)                          4851.0
#
#                                                     Maximum range (Miles)  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...                 9269.0
# Hybrid Electric Vehicle (HEV)                                         0.0
# Internal Combustion Engine (ICE)                                    236.0
# Plug-in Hybrid Electric Vehicle (PHEV)                             2997.0
#
#                                                     WLTP Imperial Low  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...                0.0
# Hybrid Electric Vehicle (HEV)                                 34851.6
# Internal Combustion Engine (ICE)                             127045.2
# Plug-in Hybrid Electric Vehicle (PHEV)                         2760.6
#
#                                                     WLTP Imperial Medium  ...  \
# Powertrain                                                                ...
# Battery Electric Vehicle (BEV) / Pure Electric ...                   0.0  ...
# Hybrid Electric Vehicle (HEV)                                    42863.7  ...
# Internal Combustion Engine (ICE)                                164618.6  ...
# Plug-in Hybrid Electric Vehicle (PHEV)                            2829.2  ...
#
#                                                     Electric Range City Km  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...                 19261.0
# Hybrid Electric Vehicle (HEV)                                          0.0
# Internal Combustion Engine (ICE)                                       0.0
# Plug-in Hybrid Electric Vehicle (PHEV)                              3040.0
#
#                                                     Noise Level dB(A)  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...             2900.4
# Hybrid Electric Vehicle (HEV)                                 59957.8
# Internal Combustion Engine (ICE)                             254498.0
# Plug-in Hybrid Electric Vehicle (PHEV)                         6353.0
#
#                                                     Emissions CO [mg/km]  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...                   0.0
# Hybrid Electric Vehicle (HEV)                                   195796.0
# Internal Combustion Engine (ICE)                                882233.0
# Plug-in Hybrid Electric Vehicle (PHEV)                           25666.0
#
#                                                     THC Emissions [mg/km]  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...                    0.0
# Hybrid Electric Vehicle (HEV)                                     15472.0
# Internal Combustion Engine (ICE)                                  66588.0
# Plug-in Hybrid Electric Vehicle (PHEV)                             1152.0
#
#                                                     Emissions NOx [mg/km]  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...                    0.0
# Hybrid Electric Vehicle (HEV)                                     17364.0
# Internal Combustion Engine (ICE)                                 109596.0
# Plug-in Hybrid Electric Vehicle (PHEV)                             1308.0
#
#                                                     THC + NOx Emissions [mg/km]  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...                          0.0
# Hybrid Electric Vehicle (HEV)                                           25666.0
# Internal Combustion Engine (ICE)                                        94138.0
# Plug-in Hybrid Electric Vehicle (PHEV)                                    860.0
#
#                                                     Particulates [No.] [mg/km]  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...                        0.00
# Hybrid Electric Vehicle (HEV)                                           140.27
# Internal Combustion Engine (ICE)                                       1683.05
# Plug-in Hybrid Electric Vehicle (PHEV)                                    5.75
#
#                                                     RDE NOx Urban  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...            0.0
# Hybrid Electric Vehicle (HEV)                             12882.0
# Internal Combustion Engine (ICE)                         196056.0
# Plug-in Hybrid Electric Vehicle (PHEV)                     2402.0
#
#                                                     RDE NOx Combined  \
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...               0.0
# Hybrid Electric Vehicle (HEV)                                12842.0
# Internal Combustion Engine (ICE)                            213874.0
# Plug-in Hybrid Electric Vehicle (PHEV)                        3122.0
#
#                                                     Unnamed: 45
# Powertrain
# Battery Electric Vehicle (BEV) / Pure Electric ...          0.0
# Hybrid Electric Vehicle (HEV)                               0.0
# Internal Combustion Engine (ICE)                            0.0
# Plug-in Hybrid Electric Vehicle (PHEV)                      0.0
#
# [4 rows x 35 columns]

# %%
df_d20_evs = df_d20[df_d20['Powertrain'] == 'Battery Electric Vehicle (BEV) / Pure Electric Vehicle / Electric Vehicle (EV)']
df_d20_evs.head()
# Out:
#     Manufacturer           Model                                Description  \
# 290      CITROEN          New C4  100kW Electric Vehicle with 50kWh battery
# 291      CITROEN          New C4  100kW Electric Vehicle with 50kWh battery
# 304      CITROEN     SpaceTourer                     50KWh Electric Vehicle
# 305      CITROEN     SpaceTourer                     50KWh Electric Vehicle
# 324           DS  DS 3 CROSSBACK                                    E-TENSE
#
#     Transmission  Engine Capacity    Fuel Type  \
# 290          NaN                0  Electricity
# 291          NaN                0  Electricity
# 304          NaN                0  Electricity
# 305          NaN                0  Electricity
# 324          NaN                0  Electricity
#
#                                             Powertrain  Engine Power (Kw)  \
# 290  Battery Electric Vehicle (BEV) / Pure Electric...              100.0
# 291  Battery Electric Vehicle (BEV) / Pure Electric...              100.0
# 304  Battery Electric Vehicle (BEV) / Pure Electric...              100.0
# 305  Battery Electric Vehicle (BEV) / Pure Electric...              100.0
# 324  Battery Electric Vehicle (BEV) / Pure Electric...                NaN
#
#      Engine Power (PS) Testing Scheme  ... Total cost / 10000 miles  \
# 290              136.0           WLTP  ...                     £308
# 291              136.0           WLTP  ...                     £334
# 304              136.0           WLTP  ...                     £463
# 305              136.0           WLTP  ...                     £567
# 324                NaN           WLTP  ...                     £342
#
#      Noise Level dB(A)  Emissions CO [mg/km]  THC Emissions [mg/km]  \
# 290               67.0                   NaN                    NaN
# 291               67.0                   NaN                    NaN
# 304               68.0                   NaN                    NaN
# 305               68.0                   NaN                    NaN
# 324               68.0                   NaN                    NaN
#
#      Emissions NOx [mg/km]  THC + NOx Emissions [mg/km]  \
# 290                    NaN                          NaN
# 291                    NaN                          NaN
# 304                    NaN                          NaN
# 305                    NaN                          NaN
# 324                    NaN                          NaN
#
#      Particulates [No.] [mg/km]  RDE NOx Urban  RDE NOx Combined  Unnamed: 45
# 290                         NaN            NaN               0.0          NaN
# 291                         NaN            NaN               0.0          NaN
# 304                         NaN            NaN               0.0          NaN
# 305                         NaN            NaN               0.0          NaN
# 324                         NaN            NaN               0.0          NaN
#
# [5 rows x 46 columns]

# %%
df_d20_evs.groupby(['Manufacturer']).sum()
# Out:
#                Engine Capacity  Engine Power (Kw)  Engine Power (PS)  \
# Manufacturer
# CITROEN                      0              400.0              544.0
# DS                           0                0.0                0.0
# HYUNDAI                      0              350.0              476.0
# JAGUAR                       0                0.0                0.0
# KIA                          0              550.0              742.0
# MERCEDES-BENZ                0              600.0              816.0
# MG MOTORS UK                 0                0.0                0.0
# NISSAN                       0                0.0                0.0
# PEUGEOT                      0              200.0              272.0
# SMART                        0              360.0              492.0
# TESLA                        0                0.0                0.0
#
#                Diesel VED Supplement  Electric energy consumption Miles/kWh  \
# Manufacturer
# CITROEN                            0                                   13.0
# DS                                 0                                    7.0
# HYUNDAI                            0                                   13.0
# JAGUAR                             0                                    2.8
# KIA                                0                                   15.8
# MERCEDES-BENZ                      0                                    5.4
# MG MOTORS UK                       0                                   14.2
# NISSAN                             0                                    3.0
# PEUGEOT                            0                                   20.0
# SMART                              0                                   21.6
# TESLA                              0                                   33.4
#
#                 wh/km  Maximum range (Km)  Maximum range (Miles)  \
# Manufacturer
# CITROEN         831.0              1138.0                  707.0
# DS              353.0               639.0                  397.0
# HYUNDAI         428.0               995.0                  618.0
# JAGUAR          220.0               470.0                  292.0
# KIA             628.0              1650.0                 1023.0
# MERCEDES-BENZ   456.0               916.0                  568.0
# MG MOTORS UK    698.0              1254.0                  778.0
# NISSAN          206.0               270.0                  168.0
# PEUGEOT        1200.0              1735.0                 1078.0
# SMART          1037.0               737.0                  455.0
# TESLA          1889.0              5126.0                 3185.0
#
#                WLTP Imperial Low  WLTP Imperial Medium  ...  \
# Manufacturer                                            ...
# CITROEN                      0.0                   0.0  ...
# DS                           0.0                   0.0  ...
# HYUNDAI                      0.0                   0.0  ...
# JAGUAR                       0.0                   0.0  ...
# KIA                          0.0                   0.0  ...
# MERCEDES-BENZ                0.0                   0.0  ...
# MG MOTORS UK                 0.0                   0.0  ...
# NISSAN                       0.0                   0.0  ...
# PEUGEOT                      0.0                   0.0  ...
# SMART                        0.0                   0.0  ...
# TESLA                        0.0                   0.0  ...
#
#                Electric Range City Km  Noise Level dB(A)  \
# Manufacturer
# CITROEN                        1663.0              270.0
# DS                              896.0              136.0
# HYUNDAI                        1507.0              202.0
# JAGUAR                          628.0               67.4
# KIA                            2282.0              279.0
# MERCEDES-BENZ                   819.0              136.0
# MG MOTORS UK                   1682.0              264.0
# NISSAN                            0.0               66.0
# PEUGEOT                        2469.0              392.0
# SMART                          1012.0              396.0
# TESLA                          6303.0              692.0
#
#                Emissions CO [mg/km]  THC Emissions [mg/km]  \
# Manufacturer
# CITROEN                         0.0                    0.0
# DS                              0.0                    0.0
# HYUNDAI                         0.0                    0.0
# JAGUAR                          0.0                    0.0
# KIA                             0.0                    0.0
# MERCEDES-BENZ                   0.0                    0.0
# MG MOTORS UK                    0.0                    0.0
# NISSAN                          0.0                    0.0
# PEUGEOT                         0.0                    0.0
# SMART                           0.0                    0.0
# TESLA                           0.0                    0.0
#
#                Emissions NOx [mg/km]  THC + NOx Emissions [mg/km]  \
# Manufacturer
# CITROEN                          0.0                          0.0
# DS                               0.0                          0.0
# HYUNDAI                          0.0                          0.0
# JAGUAR                           0.0                          0.0
# KIA                              0.0                          0.0
# MERCEDES-BENZ                    0.0                          0.0
# MG MOTORS UK                     0.0                          0.0
# NISSAN                           0.0                          0.0
# PEUGEOT                          0.0                          0.0
# SMART                            0.0                          0.0
# TESLA                            0.0                          0.0
#
#                Particulates [No.] [mg/km]  RDE NOx Urban  RDE NOx Combined  \
# Manufacturer
# CITROEN                               0.0            0.0               0.0
# DS                                    0.0            0.0               0.0
# HYUNDAI                               0.0            0.0               0.0
# JAGUAR                                0.0            0.0               0.0
# KIA                                   0.0            0.0               0.0
# MERCEDES-BENZ                         0.0            0.0               0.0
# MG MOTORS UK                          0.0            0.0               0.0
# NISSAN                                0.0            0.0               0.0
# PEUGEOT                               0.0            0.0               0.0
# SMART                                 0.0            0.0               0.0
# TESLA                                 0.0            0.0               0.0
#
#                Unnamed: 45
# Manufacturer
# CITROEN                0.0
# DS                     0.0
# HYUNDAI                0.0
# JAGUAR                 0.0
# KIA                    0.0
# MERCEDES-BENZ          0.0
# MG MOTORS UK           0.0
# NISSAN                 0.0
# PEUGEOT                0.0
# SMART                  0.0
# TESLA                  0.0
#
# [11 rows x 35 columns]

# %% [markdown]
# ## Check whether previous VCA databases have same headers

# %%
#url_d20 was imported above
url_20 = url_d20
url_19 = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/2019/data%20for%20guide%202019.zip'
url_18 = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/sept2018/September%202018%20data%20download.zip'
url_17 = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2017/download-data-for-Aug-2017-Euro-6.zip'
url_16 = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2016/download-data-for-Aug-2016-Euro-6.zip'
url_15a = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2015/download-data-for-Aug-2015-Euro-6.zip'
url_15b = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2015/download-data-for-Aug-2015-Euro-5.zip'
url_14a = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2014/download-data-for-Aug-2014-Euro-6.zip'
url_14b = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2014/download-data-for-Aug-2014-Euro-5.zip'
url_13a = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2013/download-data-for-Aug-2013-Euro-6.zip'
url_13b = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2013/download-data-for-Aug-2013-Euro-6.zip'
url_12a = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2012/download-data-for-Aug-2012-Euro-6.zip'
url_12b = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2012/download-data-for-Aug-2012-Euro-5.zip'
url_12c = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2012/download-data-for-Aug-2012-Euro-4.zip'
url_11a = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2011/download-data-for-Aug-2011-Euro-6.zip'
url_11b = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2011/download-data-for-Aug-2011-Euro-5.zip'
url_11c = 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2011/download-data-for-Aug-2011-Euro-4.zip'
url_list = [url_20, url_19, url_18, url_17, url_16, url_15a, url_15b, url_14a, url_14b, url_13a, url_13b, url_12a, url_12b, url_12c, url_11a, url_11b, url_11c]
url_names_list = ['url_20', 'url_19', 'url_18', 'url_17', 'url_16', 'url_15', 'url_14a', 'url_14b', 'url_13a', 'url_13b', 'url_12a', 'url_12b', 'url_12c', 'url_11a', 'url_11b', 'url_11c']

# %%
print(len(url_list))
# Out:
# 17

# %%
for i in range(0, 16):
# Out:
#   File "<ipython-input-10-07f5c209eddc>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
url_list[15]
# Out:
# 'https://carfueldata.vehicle-certification-agency.gov.uk/additional/aug2011/download-data-for-Aug-2011-Euro-5.zip'

# %%
df_19 = pd.read_csv(url_19, encoding='cp1252')
df_18 = pd.read_csv(url_18, encoding='cp1252')
df_17 = pd.read_csv(url_17, encoding='cp1252')
df_16 = pd.read_csv(url_16, encoding='cp1252')
df_15a = pd.read_csv(url_15a, encoding='cp1252')
df_15b = pd.read_csv(url_15b, encoding='cp1252')
df_14a = pd.read_csv(url_14a, encoding='cp1252')
df_14b = pd.read_csv(url_14b, encoding='cp1252')
df_13a = pd.read_csv(url_13a, encoding='cp1252')
df_13b = pd.read_csv(url_13b, encoding='cp1252')
df_12a = pd.read_csv(url_12a, encoding='cp1252')
df_12b = pd.read_csv(url_12b, encoding='cp1252')
df_12c = pd.read_csv(url_12c, encoding='cp1252')
df_11a = pd.read_excel(url_11a)
df_11b = pd.read_csv(url_11b, encoding='cp1252')
df_11c = pd.read_csv(url_11c, encoding='cp1252')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-e5c71f5a19c2> in <module>
#      12 df_12b = pd.read_csv(url_12b, encoding='cp1252')
#      13 df_12c = pd.read_csv(url_12c, encoding='cp1252')
# ---> 14 df_11a = pd.read_excel(url_11a)
#      15 df_11b = pd.read_csv(url_11b, encoding='cp1252')
#      16 df_11c = pd.read_csv(url_11c, encoding='cp1252')
#
# ~\.conda\envs\mot\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ~\.conda\envs\mot\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
#     335         should_close = True
# --> 336         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     337     elif engine and engine != io.engine:
#     338         raise ValueError(
#
# ~\.conda\envs\mot\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1100
#    1101             if ext != "xls" and xlrd_version >= "2":
# -> 1102                 raise ValueError(
#    1103                     f"Your version of xlrd is {xlrd_version}. In xlrd >= 2.0, "
#    1104                     f"only the xls format is supported. Install openpyxl instead."
#
# ValueError: Your version of xlrd is 2.0.1. In xlrd >= 2.0, only the xls format is supported. Install openpyxl instead.
